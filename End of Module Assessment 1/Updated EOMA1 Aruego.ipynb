# %% [markdown]
# # End-of-Module Assessment 1

# %% [markdown]
# ## Instructions
#
# Please read and follow these instructions and specifications carefully.
#
# 1. This test is available from July 22 to 11:59 PM of July 27. We will only grade this test after July 27, and we will only grade it once.
# 2. This test covers Modules 2 to 4. At this point in the course, you are expected to be familiar enough with Python to use the concepts from these modules with finesse.
# 3. Unless otherwise specified, you are not allowed to use any non-standard (i.e., not in the standard library) modules for this test. We must be strict about this on principle. For example, if you use NumPy or Pandas without permission on problems which ask you to process data, we reserve the right to give your answer no credit. If you are unsure whether you are allowed to use a library, ask. (Yes, you can use the csv and json libraries.)
# 4. Answers to problems that are hard-coded, done in another program such as Excel, or go against the learning outcomes in any other manner will be given no credit. If you are unsure whether your approach to a problem goes against the learning outcomes, ask.
# 5. You are encouraged to use only the provided code cell for each number. However, if you _need_ more cells, you may add them. If you do add more cells, make sure to label them very clearly. Code cells that are not clearly labelled will not be checked.
# 6. If you are asked to output files, please write them all to the `output` folder, even if we forget to specify the ./output prefix.
# 7. If we ask you to use an input file, please find the file in the appropriate section's folder. If it is not there, let us know.
#
# Submission instructions:
# 1. Create a NEW GitHub repository. This repository is what you will submit to the Canvas assignment to indicate that you have submitted. Name your repository SECTION-IDNUM-LASTNAME-EOMA1 (e.g., A-199999-ILAGAN-EOMA1).
# 2. Upload the contents of this folder to your repository. This includes the EOMA1.ipynb file, the output folder, and all three section folders.
# 3. To officially submit your assignment, upload the link to your GitHub repository and your duly accomplished COA to the Canvas assignment (just like the normal assignments).
#
# Some notes:
# 1. Joe made some of these items, and Joben made the others. The items will likely have different conventions in the context/briefs. Please follow them carefully anyway.

# %% [markdown]
# ## Section 1: Rudimentary Data Processing (30 points)

# %% [markdown]
# ### Context
#
# One extremely common form of data is the data shared between applications. Nowadays, when applications talk to each other, they send data in the form of JSON using Hypertext Transfer Protocol (HTTP). You will learn more about this in the next module.
#
# For this section, you are to process data from Twitter's API. The results of several requests to Twitter's API about tweets with the keyword "SONA" have been pre-saved in a `.json` file called `./section1/tweets.json`. Please run the following cell to ensure that the file loads properly.

# %%
# execute this cell to load the file

import json
# If the tweets do not load properly, change this path as necessary.
tweets_file = './section1/tweets.json'

with open(tweets_file, "r") as json_file:
    tweets = json.loads(json_file.read())

# Print contents of tweets to make sure things are okay.
# print(tweets)

# ^ on the original file (EOMA1 Aruego) I printed it out.
# I removed it here so that the github preview does not get flooded.
# I also changed End of Module Assessmen 1/<placeholder>/<placeholder> to ./<placeholder>/<placeholder>
# I placed the file within the folder, which is why I had to make the change in order for it to read the file.

# %% [markdown]
# ### 1.1
#
# Print out the number of tweets.

# %%
# CODE CELL

# CODE START

len(tweets)


# CODE END
# Out:
# 100

# %% [markdown]
# ### 1.2
#
# Create a list variable called `tweet_texts` that contains the text of the tweets contained in `tweets`.
#
# Afterwards, print `tweet_texts`.

# %%
# CODE CELL

tweet_texts = []

# CODE START

for i in tweets:
    tweet_texts.append(i['full_text'])
    

# CODE END

print(tweet_texts)

# The output should look like this.
# Out:
# ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Quédate con la persona que no te deje ir a dormir sin antes decirte "decansa,soña bonito y recuerda que te quiero mucho".', 'RT @gmanews: LOOK: Pati mga health worker, sumali sa anti-SONA rally kaninang umaga sa UP Diliman. \n\nAyon sa mga dumalo, malala ang mga pro…', "RT @leamaine2019: Hello there, my Queen @mainedcm!\xa0 I'll be attending PRRD's SONA w/ leaders across the globe so I won't be able to tweet f…", 'RT @heroangel17: SONA\nState Of No Accomplishment\n\n🤭✊', 'Difficult step .\nMere liye k ...

# %% [markdown]
# ### 1.3
#
# Remove duplicate tweet text lines and save the resulting (cleaned-up) list in the same variable `tweet_texts`.

# %%
# CODE CELL

# CODE START

tweet_texts = set(tweet_texts)

# CODE END

print(tweet_texts)
# The output should look like this.
# Out:
# {'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', '@Per_sona__ おちつきましｳﾞｵｵｵｵｪｱｱｱ', 'RT @Plaridel_DLSU: Ngayong araw isasagawa ang ikalimang SONA na nagkaroon ng mga pagbabago dahil sa pandemyang idinulot ng COVID-19. #SONA2…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', '#verivery_asc hi! please make sure to take care of yourselves! verivery! fighting!', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', "Yo, with all the attractive female OCs I've seen seeing (and falling for) lately, I might need to draw my sona doing one of these sometime soon. https://t.co/m2bdQVkqRt", "RT @cnnphilippines: Globe and PLDT shares are down at the first hour of trading today. It's the first time for market players to react to P…", 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @shujoprime: 『#週刊女性』8/4/11合併号が好評発売中！ 表紙は #ジェジュン さん☆ ソウルでの独占インタビュー＆美麗写真をお見逃しなく! #三浦春馬 さんが本誌に見せてくれた素顔の数々をグラビアで振り返ります。毎年恒例「#好きなジャニーズ #嫌いなジャ…', 'RT @JethroGamez: Tapos na ang SONA trends. Balik na tayo sa normal Twitter.\n\nAnd most especially, si Duterte pa rin ang Pangulo ng Republik…', 'Nanga @ThalaAjith_FC  tag sona tha tweets poduvom . \n\nNanga @ThalaAjith_FC  tag sona tweet poda matom. \n\nEpudiye soltu suthunga nalaiku danush &amp; sl fans la namba record ya beat panitu povanga ukanthu avungaluku pidicha fc page ku pooja podunga 😊\n#valimai #ThalaAjith #Ajithkumar', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', '@kharaa_sona_ @aadyamishraa @hiteshm09 @explorerhoon @Chandra_gupt7 @Zero_humour @aryaeddardstark @Man_isssh @nice_girl09 @vishal_saini_vs @ladywithflaws @sagarcasm @vaderakash @LoyalSachinFan @oldschoolmonk @tree_lochan @Singhlicious @nishacharr @pubgkadeewana @roooossshhiiiii', '@ReaperSZN__ Soooo..... probably never 😅 https://t.co/TM83uYrE5e', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @SB19TrendsPH: [TAG UPDATE]\n\nTo give way to discussions related to SONA 2020 held earlier this afternoon, we would like to request to dr…', '@DrawzSona If its Sona, we roll with it B)', 'RT @mariaressa: “Walang sustansya”: Celebrities react to Duterte’s 5th SONA https://t.co/pvuEZoILCj', 'RT @itsyaboiraff: Joseph Morong listening while typing the minutes of SONA 2020. https://t.co/NQ0ZQWKJ2d', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", 'RT @itsJayEMD: Buti pa ang mga pupunta sa SONA, may mandatory RT-PCR. KAming mga humaharap sa pandemya, pahirapan pa. Taena nyo.', "I actually watched the SONA attentively, but I don't recall him saying this???? is this even true??? https://t.co/pFoUCUwxiA", 'RT @benok_castillo: Ikumpara ang SONA sa testimonya ni Nanay.', 'RT @kaisipangabitan: SONA 2020 (Dir. Joyce Bernal) https://t.co/dX9oeSFbW2', 'RT @boymejo: Replay of my YouTube livestream on my reaction to the SONA esp with regard to #FranklinDrilon https://t.co/7acRwA6X6Q', 'RT @dailyguardianph: Neither the lingering threat of the COVID-19 nor the pouring rain failed to stop groups from protesting the policies o…', 'RT @1969Enigma: $SONA $SONA.CA #SONA @SonaNanotech @SONA_CSO \n\nhttps://t.co/gNUeg7g1LG', "This health emergency stretched the government’s resources to its limits. In response, the Office of the President worked closely with Congress for the quick passage of the Bayanihan to Heal as One Act.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", "We also provided  ...

# %% [markdown]
# ### 1.4
#
# We will now perform a very simple word count on the texts.
#
# We have provided a dictionary called `words_dict`. Your code in the next cell should process the tweets such that `words_dict` will contain key-value pairs where the key is a unique word and where the value is the number of times the word appears across all of the texts.
#
# For each text, remove the characters contained in the following string:
#
# `"&$@[].,'#()-\"!?’_"`
#
# Please ignore the newline (`\n`) character.

# %%
# CODE CELL
words_dict = {}

remove_chars = "&$@[].,'#()-\"!?’_"

# CODE START
words = []
unique_words = []

tweet_texts = list(tweet_texts)

for i in range(len(tweet_texts)):
    for j in remove_chars:
        tweet_texts[i] = tweet_texts[i].replace(j,"")


for u in tweet_texts:
    words += u.split()

for y in range(len(words)):
    words[y] = words[y].upper()
    
unique_words = set(words)


for x in unique_words: 
    value = 0
    for z in words:
        if x == z:
            value += 1
        else: 
            pass
    words_dict.update({x:value})

# CODE END

# Your output should look like this.
print(words_dict)
# Out:
# {'AADYAMISHRAA': 1, 'SCHOOL': 1, 'VIOLATION': 1, 'RECUERDA': 1, 'WATCHMEJAYJAY:': 1, 'TAMA': 1, 'WHILE': 1, 'REIMPOSITION': 1, 'IMEE': 1, 'FC': 2, 'THIS': 7, 'IMPACT': 1, 'HTTPS://TCO/4MH3XW4KNC': 1, 'STOP': 1, 'YOURSELVES': 1, 'TATAY': 1, 'NEB': 1, 'MAGALALA': 1, 'BILLI': 1, 'GIVE': 2, 'CONFERENCE': 1, 'ATTRACTIVE': 1, 'JAO': 1, 'QUICK': 1, 'HTTPS://TCO/X0AW68YUY5': 1, 'ONLY': 2, 'LETHAL': 1, 'HAI': 1, 'AFFECTED': 1, 'ANTISONA': 1, 'HERE': 2, 'BHAGVATEEBHEEL': 1, 'KABILA': 1, 'NGAYONG': 2, 'SAID': 2, 'MIKEDEFENSOR:': 1, 'DEGI': 1, 'DIOK…': 1, 'ALWAYS': 1, 'COVID19': 7, 'HTTPS://TCO/FJLTIQIW82': 1, 'HARRY': 1, 'INDIANPANDAA': 1, 'DESIGNED': 1, 'REMNANTS': 1, '2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤': 1, 'KABATAANPL': 1, 'CURRENT': 1, 'SONA': 65, 'HOUR': 1, 'MEASURES': 1, 'PLEASE': 2, 'INJECTION': 1, 'THANK': 1, '650000': 1, 'NAGNEGATIBO': 1, 'STATEMENT': 1, 'QUÉDATE': 1, 'MALALA': 1, 'WAY': 4, 'NAKITA': 2, 'SENATOR': 1, 'SUMAILALIM': 1, '\\ジェジュンの優しく、深い歌声がしみわたる/': 1, 'SL': 1, 'DREW': 1, 'BA': 2, 'WATCHING': 1, 'QUEZON': 1, 'PAHINA': 1, 'BTPRA…': 1, 'FUN': 1, 'BLDG': 1, 'TOTALLY': 2, 'PANGULO': 2, 'HI': 1, 'MALACAÑANG': 1, 'MARCOS:': 1, 'KAYO': 1, 'HAHAHA': 1, 'OPPORTUNITIES': 1, 'SEMESTER': 1, 'BIR': 1, 'KARPIKA': 1, 'SIYANG': 1, 'AJITHKUMAR': 2, 'ON': 5, 'BATAO': 1, '3SAAL': 1, 'ONLINE': 1, 'WAGE': 1, 'DIR': 1, 'FORCES': 1, 'LATELY': 1, 'RESPONSE': 2, 'SONAGKAISA2020': 1, 'VIA': 1, 'MANISSSH': 1, 'TWITTER': 1, 'WORKED': 1, 'SB19TRENDSPH:': 1, 'VIBE': 1, 'LANG': 3, 'SI': 4, 'LINGERING': 1, 'INYO': 1, 'THAT': 7, 'MIGUEL': 1, 'SONAGKAISA': 3, 'PRESIDENCY': 1, 'INVITED': 1, 'JADINETRASH:': 1, 'HANSSENSANTHONY:': 1, 'DRAWZSONA': 1, 'COUNCIL': 3, 'READ:': 1, '…': 1, 'PRIORITY': 1, 'DIN': 1, 'LAW': 2, 'DISPLACED': 1, 'PAGBABAGO': 1, 'NIYO': 1, 'HTTPS://TCO/GNUEG7G1LG': 1, 'CRISIS': 1, 'STANDS': 1, 'ABOUT': 2, 'RESPOND': 1, 'DISCUSSIONS': 2, 'ALTABSCBN:': 1, 'KAMING': 1, '1969ENIGMA:': 1, 'NANG': 1, 'KANINANG': 1, 'CALLS': 1, 'EARLIER': 2, 'B': 1, 'PRES:': 1, 'FUCKING': 1, 'CLEARLY': 1, 'GLOBE': 3, 'INUTUSAN': 1, 'SEEING': 1, 'PREENPH:': 1, 'HTTPS://TCO/TM83UYRE5E': 1, 'VADERAKASH': 1, 'BENOKCASTILLO:': 1, 'HE': 2, 'KAISIPANGABITAN:': 1, '|': 2, '🎁タワレコ特典はアナザージャ…': 1, 'AKO': 2, 'AMING': 1, 'BEEN': 1, 'CAUSTICKANYA': 1, 'RECORD': 1, 'BRATBIUSH': 1, 'PHILIPPINE': 1, 'HTTPS://TCO/NIEAEXKBCU': 1, 'JEEVANPARIHAR15:': 1, 'TRENDS': 1, 'STYLE': 1, 'DAILYGUARDIANPH:': 1, 'OFFICE': 1, 'さんが本誌に見せてくれた素顔の数々をグラビアで振り返ります。毎年恒例「好きなジャニーズ': 1, 'PASSAGE': 2, 'KRNA': 1, 'HURDLES': 1, 'LA': 2, 'ELAN': 1, 'USUALLY': 1, 'WILL': 1, 'READING': 1, 'NEVER': 1, 'NILOCKDOWN': 1, 'LEGAL': 1, 'ITSYABOIRAFF:': 1, 'CAPITAL': 1, 'PASAND': 1, '“WALANG': 1, 'DOING': 1, 'JETHROGAMEZ:': 1, 'NASA': 1, 'HOGA': 2, 'KENDISININ': 1, 'PUSHING': 1, '嫌いなジャ…': 1, 'HEALTH': 2, 'ITSACSLIFE:': 1, 'NANAY': 1, 'ATTENTIVELY': 1, 'DR…': 1, 'WIL…': 1, 'KIRUIU': 1, 'YAN': 1, 'ESP': 1, 'PUBGKADEEWANA': 1, 'ELSE': 1, 'NAINSPIRE': 1, 'WATCH': 1, 'CAN': 2, 'ACTUALLY': 1, 'CITY': 1, 'REACH': 2, 'ジェジュン': 1, 'YES': 1, 'TAKE': 1, 'ANTHRO': 1, 'NG': 14, 'MGA': 12, 'LIVE…': 1, 'NAKANOOD': 1, 'INDIA': 1, '27': 1, 'PRRDS': 1, 'ROHITME': 1, 'GOVERNMENTS': 2, 'PRESS': 3, 'HIGH': 1, 'MUJHE': 2, 'THOUGHTS': 1, 'KO': 4, 'FASTNESS': 1, 'YOUR': 2, 'PROTESTA': 2, 'NANGA': 2, 'ANTES': 1, 'ITS': 3, 'TAYO': 2, 'SONATOTOO': 1, 'TAYONG': 2, 'ABLE': 1, 'WAG': 2, 'SOOOO': 1, 'SAME': 2, 'HIS': 5, 'VERIVERYASC': 1, 'RUHANI': 1, 'GRADE': 1, 'MINUTES': 1, 'DUHHHH': 1, 'KASO': 1, 'ツアー映像『JJUN': 1, 'BEYEFENDIYE': 1, 'COVERS～』本日入荷しました🙌': 1, 'PANAWAGAN': 1, 'VISHALSAINIVS': 1, 'LISTENED': 1, 'SUMALI': 1, 'ZEROHUMOUR': 1, 'AUDACITY': 1, 'HASHTAGNIKKO13:': 1, 'HINDI': 2, 'SIN': 1, 'MUKHA': 1, 'MET': 1, 'UNA': 1, 'PATI': 1, '😯😯': 1, 'ERKANGA': 1, 'SHARES': 2, 'CNNPHILIPPINES:': 2, 'ARYAEDDARDSTARK': 1, 'OFFICIALS': 1, 'OSKO': 1, 'EPUDIYE': 1, 'AJMALJAMI': 1, 'NILA': 1, 'REMAINDER': 1, 'HTTPS://TCO/SJCNU8QTUO': 1, 'RANTS': 1, 'DECRY': 1, 'USAPINGLACSON:': 1, 'SUTHUNGA': 1, 'KWENTA': 1, 'RIN': 4, 'PE': 1, 'MONDAY': 1, 'NONSENSE': 1, 'CLOS ...

# %% [markdown]
# ### 1.5
#
# Now, we would like to have a list of words and counts sorted by count in descending order.
#
# Define a new list variable named `words_list` containing **tuples**, where each tuple is as follows:
#
# `(word, count)`
#
# Print the contents of `words_list`.
#
# Sample output is provided below.

# %%
# CODE CELL

# CODE START

words_list = []
for k, v in words_dict.items():
    words_list.append((k,v))

# CODE END

# The output should look like this. 
print(words_list)
# Out:
# [('AADYAMISHRAA', 1), ('SCHOOL', 1), ('VIOLATION', 1), ('RECUERDA', 1), ('WATCHMEJAYJAY:', 1), ('TAMA', 1), ('WHILE', 1), ('REIMPOSITION', 1), ('IMEE', 1), ('FC', 2), ('THIS', 7), ('IMPACT', 1), ('HTTPS://TCO/4MH3XW4KNC', 1), ('STOP', 1), ('YOURSELVES', 1), ('TATAY', 1), ('NEB', 1), ('MAGALALA', 1), ('BILLI', 1), ('GIVE', 2), ('CONFERENCE', 1), ('ATTRACTIVE', 1), ('JAO', 1), ('QUICK', 1), ('HTTPS://TCO/X0AW68YUY5', 1), ('ONLY', 2), ('LETHAL', 1), ('HAI', 1), ('AFFECTED', 1), ('ANTISONA', 1), ('HERE', 2), ('BHAGVATEEBHEEL', 1), ('KABILA', 1), ('NGAYONG', 2), ('SAID', 2), ('MIKEDEFENSOR:', 1), ('DEGI', 1), ('DIOK…', 1), ('ALWAYS', 1), ('COVID19', 7), ('HTTPS://TCO/FJLTIQIW82', 1), ('HARRY', 1), ('INDIANPANDAA', 1), ('DESIGNED', 1), ('REMNANTS', 1), ('2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤', 1), ('KABATAANPL', 1), ('CURRENT', 1), ('SONA', 65), ('HOUR', 1), ('MEASURES', 1), ('PLEASE', 2), ('INJECTION', 1), ('THANK', 1), ('650000', 1), ('NAGNEGATIBO', 1), ('STATEMENT', 1), ('QUÉDATE', 1), ('MALALA', 1), ('WAY', 4), ('NAKITA', 2), ('SENATOR', 1), ('SUMAILALIM', 1), ('\\ジェジュンの優しく、深い歌声がしみわたる/', 1), ('SL', 1), ('DREW', 1), ('BA', 2), ('WATCHING', 1), ('QUEZON', 1), ('PAHINA', 1), ('BTPRA…', 1), ('FUN', 1), ('BLDG', 1), ('TOTALLY', 2), ('PANGULO', 2), ('HI', 1), ('MALACAÑANG', 1), ('MARCOS:', 1), ('KAYO', 1), ('HAHAHA', 1), ('OPPORTUNITIES', 1), ('SEMESTER', 1), ('BIR', 1), ('KARPIKA', 1), ('SIYANG', 1), ('AJITHKUMAR', 2), ('ON', 5), ('BATAO', 1), ('3SAAL', 1), ('ONLINE', 1), ('WAGE', 1), ('DIR', 1), ('FORCES', 1), ('LATELY', 1), ('RESPONSE', 2), ('SONAGKAISA2020', 1), ('VIA', 1), ('MANISSSH', 1), ('TWITTER', 1), ('WORKED', 1), ('SB19TRENDSPH:', 1), ('VIBE', 1), ('LANG', 3), ('SI', 4), ('LINGERING', 1), ('INYO', 1), ('THAT', 7), ('MIGUEL', 1), ('SONAGKAISA', 3), ('PRESIDENCY', 1), ('INVITED', 1), ('JADINETRASH:', 1), ('HANSSENSANTHONY:', 1), ('DRAWZSONA', 1), ('COUNCIL', 3), ('READ:', 1), ('…', 1), ('PRIORITY', 1), ('DIN', 1), ('LAW', 2), ('DISPLACED', 1), ('PAGBABAGO', 1), ('NIYO', 1), ('HTTPS://TCO/GNUEG7G1LG', 1), ('CRISIS', 1), ('STANDS', 1), ('ABOUT', 2), ('RESPOND', 1), ('DISCUSSIONS', 2), ('ALTABSCBN:', 1), ('KAMING', 1), ('1969ENIGMA:', 1), ('NANG', 1), ('KANINANG', 1), ('CALLS', 1), ('EARLIER', 2), ('B', 1), ('PRES:', 1), ('FUCKING', 1), ('CLEARLY', 1), ('GLOBE', 3), ('INUTUSAN', 1), ('SEEING', 1), ('PREENPH:', 1), ('HTTPS://TCO/TM83UYRE5E', 1), ('VADERAKASH', 1), ('BENOKCASTILLO:', 1), ('HE', 2), ('KAISIPANGABITAN:', 1), ('|', 2), ('🎁タワレコ特典はアナザージャ…', 1), ('AKO', 2), ('AMING', 1), ('BEEN', 1), ('CAUSTICKANYA', 1), ('RECORD', 1), ('BRATBIUSH', 1), ('PHILIPPINE', 1), ('HTTPS://TCO/NIEAEXKBCU', 1), ('JEEVANPARIHAR15:', 1), ('TRENDS', 1), ('STYLE', 1), ('DAILYGUARDIANPH:', 1), ('OFFICE', 1), ('さんが本誌に見せてくれた素顔の数々をグラビアで振り返ります。毎年恒例「好きなジャニーズ', 1), ('PASSAGE', 2), ('KRNA', 1), ('HURDLES', 1), ('LA', 2), ('ELAN', 1), ('USUALLY', 1), ('WILL', 1), ('READING', 1), ('NEVER', 1), ('NILOCKDOWN', 1), ('LEGAL', 1), ('ITSYABOIRAFF:', 1), ('CAPITAL', 1), ('PASAND', 1), ('“WALANG', 1), ('DOING', 1), ('JETHROGAMEZ:', 1), ('NASA', 1), ('HOGA', 2), ('KENDISININ', 1), ('PUSHING', 1), ('嫌いなジャ…', 1), ('HEALTH', 2), ('ITSACSLIFE:', 1), ('NANAY', 1), ('ATTENTIVELY', 1), ('DR…', 1), ('WIL…', 1), ('KIRUIU', 1), ('YAN', 1), ('ESP', 1), ('PUBGKADEEWANA', 1), ('ELSE', 1), ('NAINSPIRE', 1), ('WATCH', 1), ('CAN', 2), ('ACTUALLY', 1), ('CITY', 1), ('REACH', 2), ('ジェジュン', 1), ('YES', 1), ('TAKE', 1), ('ANTHRO', 1), ('NG', 14), ('MGA', 12), ('LIVE…', 1), ('NAKANOOD', 1), ('INDIA', 1), ('27', 1), ('PRRDS', 1), ('ROHITME', 1), ('GOVERNMENTS', 2), ('PRESS', 3), ('HIGH', 1), ('MUJHE', 2), ('THOUGHTS', 1), ('KO', 4), ('FASTNESS', 1), ('YOUR', 2), ('PROTESTA', 2), ('NANGA', 2), ('ANTES', 1), ('ITS', 3), ('TAYO', 2), ('SONATOTOO', 1), ('TAYONG', 2), ('ABLE', 1), ('WAG', 2), ('SOOOO', 1), ('SAME', 2), ('HIS', 5), ('VERIVERYASC', 1), ('RUHANI', 1), ('GRADE', 1), ('MINUTES', 1), ('DUHHHH', 1), ('KASO', 1), ('ツアー映像『JJUN', 1), ('BEYEFENDIYE', 1), ('COVERS～』本日入荷しました🙌', 1), ('PANAWAGAN ...

# %% [markdown]
# ### 1.6
#
# Sort the list by count (which is the second element of each tuple) in descending (or reverse) order.
#
# Print the contents of the newly-sorted list `words_list`.
#
# Sample output shown below.

# %%
# CODE CELL

# CODE START

words_list.sort(key=lambda x:x[1], reverse = True)

# CODE END

#source: https://www.kite.com/python/answers/how-to-sort-a-list-of-tuples-by-the-second-value-in-python

# The output should look like this.
print(words_list)
# Out:
# [('SONA', 65), ('THE', 55), ('RT', 53), ('TO', 36), ('SA', 34), ('OF', 30), ('ANG', 20), ('NA', 19), ('NG', 14), ('AND', 14), ('5TH', 13), ('MGA', 12), ('IN', 11), ('FOR', 11), ('DUTERTE', 10), ('DUTERTES', 10), ('WE', 9), ('MY', 8), ('PRESIDENT', 8), ('WITH', 8), ('THIS', 7), ('COVID19', 7), ('THAT', 7), ('2020', 7), ('NI', 7), ('A', 6), ('MAY', 6), ('AMP;', 6), ('I', 6), ('ON', 5), ('HIS', 5), ('PA', 5), ('UP', 5), ('IS', 5), ('TAG', 5), ('WAY', 4), ('SI', 4), ('KO', 4), ('RIN', 4), ('DI', 4), ('STATE', 4), ('YUNG', 4), ('PRES', 4), ('YOU', 4), ('KA', 4), ('SONA2020', 4), ('ROA', 4), ('THEY', 4), ('YA', 4), ('STUDENT', 4), ('FIRST', 4), ('RODRIGO', 4), ('LANG', 3), ('SONAGKAISA', 3), ('COUNCIL', 3), ('GLOBE', 3), ('PRESS', 3), ('ITS', 3), ('FROM', 3), ('IF', 3), ('DURING', 3), ('KHARAASONA', 3), ('BEFORE', 3), ('RAPPLERDOTCOM:', 3), ('ARAW', 3), ('ONE', 3), ('HER', 3), ('OWN', 3), ('NAMAN', 3), ('ME', 3), ('HIM', 3), ('LIKE', 3), ('CONGRESS', 3), ('WOULD', 3), ('THA', 3), ('EVERYONE', 3), ('DAPAT', 3), ('SILA', 3), ('AT', 3), ('FC', 2), ('GIVE', 2), ('ONLY', 2), ('HERE', 2), ('NGAYONG', 2), ('SAID', 2), ('PLEASE', 2), ('NAKITA', 2), ('BA', 2), ('TOTALLY', 2), ('PANGULO', 2), ('AJITHKUMAR', 2), ('RESPONSE', 2), ('LAW', 2), ('ABOUT', 2), ('DISCUSSIONS', 2), ('EARLIER', 2), ('HE', 2), ('|', 2), ('AKO', 2), ('PASSAGE', 2), ('LA', 2), ('HOGA', 2), ('HEALTH', 2), ('CAN', 2), ('REACH', 2), ('GOVERNMENTS', 2), ('MUJHE', 2), ('YOUR', 2), ('PROTESTA', 2), ('NANGA', 2), ('TAYO', 2), ('TAYONG', 2), ('WAG', 2), ('SAME', 2), ('HINDI', 2), ('SHARES', 2), ('CNNPHILIPPINES:', 2), ('NADINE', 2), ('5', 2), ('KACHRA', 2), ('BE', 2), ('THROUGH', 2), ('WERE', 2), ('【ジェジュン】', 2), ('SIYA', 2), ('WHAT', 2), ('HELD', 2), ('UPDATE', 2), ('TE', 2), ('SABI', 2), ('ACT', 2), ('NEW', 2), ('HA', 2), ('EXECUTIVE', 2), ('KATRINADOMINGO', 2), ('DONT', 2), ('STEP', 2), ('RIGHTS', 2), ('MESSAGE', 2), ('SENATE', 2), ('TOWERNAMBA:', 2), ('21', 2), ('OFWS', 2), ('MATAPOS', 2), ('PAGE', 2), ('COVID', 2), ('AGAINST', 2), ('AFTER', 2), ('WAR', 2), ('DILIMAN', 2), ('WHICH', 2), ('WONT', 2), ('TWEET', 2), ('KANYANG', 2), ('TEST', 2), ('COVERS', 2), ('PROVIDED', 2), ('WAS', 2), ('NO', 2), ('OUR', 2), ('FANS', 2), ('BILLS', 2), ('GET', 2), ('KU', 2), ('DRILON', 2), ('PERSONA', 2), ('ZUBIRI', 2), ('POSTSONA', 2), ('THALAAJITHFC', 2), ('GROUPS', 2), ('LEADER', 2), ('LOOK:', 2), ('PRESIDENTS', 2), ('F…', 2), ('THALAAJITH', 2), ('NATION', 2), ('PARA', 2), ('WALANG', 2), ('TIME', 2), ('PROTEST', 2), ('GMANEWS:', 2), ('WHY', 2), ('KAR', 2), ('PANDEMIC', 2), ('PERO', 2), ('ALSO', 2), ('FRANKLIN', 2), ('BUT', 2), ('BAYANIHAN', 2), ('PALA', 2), ('KUNG', 2), ('HAVE', 2), ('MABUTI', 2), ('WAKASONA2020', 2), ('REQUEST', 2), ('REAPERSZN', 2), ('CLEAR', 2), ('BHAI', 2), ('SAAN', 2), ('REACT', 2), ('QUE', 2), ('MARACEPEDA', 2), ('AGAIN', 2), ('ANCALERTS:', 2), ('TAPOS', 2), ('RELATED', 2), ('AFTERNOON', 2), ('AS', 2), ('EVEN', 2), ('VALIMAI', 2), ('HUMAN', 2), ('AADYAMISHRAA', 1), ('SCHOOL', 1), ('VIOLATION', 1), ('RECUERDA', 1), ('WATCHMEJAYJAY:', 1), ('TAMA', 1), ('WHILE', 1), ('REIMPOSITION', 1), ('IMEE', 1), ('IMPACT', 1), ('HTTPS://TCO/4MH3XW4KNC', 1), ('STOP', 1), ('YOURSELVES', 1), ('TATAY', 1), ('NEB', 1), ('MAGALALA', 1), ('BILLI', 1), ('CONFERENCE', 1), ('ATTRACTIVE', 1), ('JAO', 1), ('QUICK', 1), ('HTTPS://TCO/X0AW68YUY5', 1), ('LETHAL', 1), ('HAI', 1), ('AFFECTED', 1), ('ANTISONA', 1), ('BHAGVATEEBHEEL', 1), ('KABILA', 1), ('MIKEDEFENSOR:', 1), ('DEGI', 1), ('DIOK…', 1), ('ALWAYS', 1), ('HTTPS://TCO/FJLTIQIW82', 1), ('HARRY', 1), ('INDIANPANDAA', 1), ('DESIGNED', 1), ('REMNANTS', 1), ('2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤', 1), ('KABATAANPL', 1), ('CURRENT', 1), ('HOUR', 1), ('MEASURES', 1), ('INJECTION', 1), ('THANK', 1), ('650000', 1), ('NAGNEGATIBO', 1), ('STATEMENT', 1), ('QUÉDATE', 1), ('MALALA', 1), ('SENATOR', 1), ('SUMAILALIM', 1), ('\\ジェジュンの優しく、深い歌声がしみわたる/', 1), ('SL', 1), ('DREW', 1), ('WATCHING', 1), ('QUEZON', 1), ('PAHINA', 1), ('BTPRA…', 1), ('FUN', 1), ('BLDG',  ...

# %% [markdown]
# ### 1.7
#
# Print out the top 5 words (based on count).
#
# Take note of the formatting below (i.e. one line per print output).
#
# Sample output shown below.

# %%
# CODE CELL

# CODE START

rank = 0

for b in range(len(words_list[0:5])):
    rank += 1
    print(f"{rank} {words_list[b]}")

# CODE END

# The output should look like this.
# Out:
# 1 ('SONA', 65)
# 2 ('THE', 55)
# 3 ('RT', 53)
# 4 ('TO', 36)
# 5 ('SA', 34)

# %% [markdown]
# ### 1.8
#
# Write a new csv file `./output/wordcount.csv` with format like so:
#
# `word,count`
# `SONA,65`
# `THE,55`
# `RT,53`
# `TO,36`
# `SA,34`
# `...`

# %%
# CODE CELL
import csv
import json

# CODE START

with open ("./output/wordcount.csv","w") as csvfile: 
    csvwriter = csv.writer(csvfile)
    csvfile.write("word, count")
    csvwriter.writerow("")

    for r in words_list:
        csvwriter.writerow(r)

# CODE END

# %% [markdown]
# Perform a `diff` or `fc` operation between your output file and the file named `wordcount-test.csv` which should be included in `section1`. Make sure there are no differences.
#
# **IMPORTANT**: Please make sure that you submit wordcount.csv along with the rest of your files.

# %% [markdown]
# ## Section 2: Reports for the Registrar (55 points)

# %% [markdown]
# ### Context
#
# Data is rarely in the form in which you want it. In this section of the assessment, you are doing consulting work for Ateneo's Office of the Registrar. They managed to collect the enlistment data for 4410 students through a Google Form. The form was not designed in such a way that the collected data is immediately usable, so they hired you to process their raw data into more appropriate forms.
#
# Please run the following cell to load the file.

# %%
# execute this cell to load the file
import json

file_path = './section2/student-enrollment-data.json'

with open(file_path, 'r') as f:
    student_data = json.load(f)
    
# Print the first few items of this file to check that it worked properly
# Please infer and understand the schema of this file.
print(student_data[:3])
# Out:
# [{'enlistment': [{'course code': 'UK 60', 'section': 'A'}, {'course code': 'GF 24', 'section': 'B'}, {'course code': 'ME 40', 'section': 'B'}, {'course code': 'VY 44', 'section': 'D'}, {'course code': 'EN 94', 'section': 'B'}], 'id': '201001', 'paid': True, 'school': 'SOSE', 'year level': 2}, {'enlistment': [{'course code': 'EQ 61', 'section': 'D'}, {'course code': 'UZ 22', 'section': 'B'}, {'course code': 'KS 36', 'section': 'B'}, {'course code': 'VH 63', 'section': 'A'}, {'course code': 'IW 81', 'section': 'C'}], 'id': '211002', 'paid': True, 'school': 'JGSOM', 'year level': 1}, {'enlistment': [{'course code': 'WE 15', 'section': 'D'}, {'course code': 'ZP 68', 'section': 'A'}, {'course code': 'GI 78', 'section': 'A'}, {'course code': 'GK 72', 'section': 'C'}, {'course code': 'FA 24', 'section': 'D'}, {'course code': 'UJ 28', 'section': 'A'}], 'id': '201003', 'paid': True, 'school': 'JGSOM', 'year level': 2}]

# %% [markdown]
# ### 2.1
#
# The first report the Registrar needs is a summary of all courses being offered. They want this report in the form of a **dictionary** whose keys are unique course codes and whose values are dictionaries with a single key-value pair describing the sections available for that course code.
#
# Here is the schema of the desired output:
#
# `{`
# &nbsp;&nbsp;&nbsp;&nbsp;`course_code: {`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"sections": [sections]`
# &nbsp;&nbsp;&nbsp;&nbsp;`}`
# `}`
#
# A dictionary called `courses` is provided to you in the following cell. Using `student_data`, populate `courses` with the data the Registrar needs.
#
# Dump this file as `./output/courses-output.json`.
#
# Additional specifications:
# 1. Sort the list of sections alphabetically.
#
# Sample output is provided in `./section2/courses-sample-output.json`.

# %%
# CODE CELL
import json
courses = {}

# CODE START

course_list = []

for i in range(len(student_data)):
    for j in range(len(student_data[i]["enlistment"])):
        course_list.append(student_data[i]["enlistment"][j]["course code"])

course_list = list(set(course_list))

for z in course_list:
    section = []
    for x in range(len(student_data)):
        for y in range(len(student_data[x]["enlistment"])):
            if student_data[x]["enlistment"][y]["course code"] == z:
                section.append(student_data[x]["enlistment"][y]["section"])
    section = list(set(section))
    section.sort()
    courses.update(
                    {
                    z:{
                       "sections" : section
                      }
                    }
                  )
    
with open('./output/courses-output.json','w') as jsonfile:
    json.dump(courses,jsonfile)
    
# CODE END

# The output should look like this.
courses
# Out:
# {'UJ 28': {'sections': ['A', 'B', 'C']},
#  'GM 72': {'sections': ['A']},
#  'MC 25': {'sections': ['A', 'B']},
#  'UZ 22': {'sections': ['A', 'B', 'C']},
#  'LV 41': {'sections': ['A', 'B', 'C', 'D']},
#  'MU 79': {'sections': ['A', 'B']},
#  'KD 33': {'sections': ['A']},
#  'AX 43': {'sections': ['A']},
#  'SN 88': {'sections': ['A']},
#  'RT 81': {'sections': ['A']},
#  'HW 19': {'sections': ['A']},
#  'IW 81': {'sections': ['A', 'B', 'C']},
#  'YB 54': {'sections': ['A', 'B', 'C', 'D']},
#  'YQ 49': {'sections': ['A', 'B']},
#  'WE 15': {'sections': ['A', 'B', 'C', 'D']},
#  'GI 78': {'sections': ['A']},
#  'ZB 82': {'sections': ['A']},
#  'FX 96': {'sections': ['A']},
#  'LJ 29': {'sections': ['A', 'B']},
#  'ME 40': {'sections': ['A', 'B', 'C']},
#  'GK 72': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']},
#  'FA 24': {'sections': ['A', 'B', 'C', 'D']},
#  'KS 36': {'sections': ['A', 'B', 'C']},
#  'VY 44': {'sections': ['A', 'B', 'C', 'D', 'E']},
#  'TS 66': {'sections': ['A']},
#  'FZ 18': {'sections': ['A']},
#  'SE 79': {'sections': ['A', 'B', 'C', 'D']},
#  'BN 85': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']},
#  'ZJ 82': {'sections': ['A', 'B', 'C', 'D', 'E']},
#  'VH 63': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']},
#  'ZP 68': {'sections': ['A']},
#  'KC 22': {'sections': ['A', 'B', 'C', 'D']},
#  'OG 37': {'sections': ['A', 'B', 'C', 'D']},
#  'KD 10': {'sections': ['A', 'B', 'C']},
#  'TT 59': {'sections': ['A', 'B']},
#  'YD 55': {'sections': ['A', 'B', 'C', 'D']},
#  'EN 94': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']},
#  'HK 84': {'sections': ['A']},
#  'VC 62': {'sections': ['A', 'B', 'C']},
#  'PG 71': {'sections': ['A', 'B', 'C']},
#  'YS 74': {'sections': ['A', 'B', 'C']},
#  'UK 70': {'sections': ['A', 'B', 'C', 'D', 'E']},
#  'EQ 61': {'sections': ['A', 'B', 'C', 'D']},
#  'GV 12': {'sections': ['A']},
#  'AI 41': {'sections': ['A', 'B', 'C', 'D', 'E']},
#  'VS 18': {'sections': ['A']},
#  'UK 60': {'sections': ['A']},
#  'QR 51': {'sections': ['A']},
#  'GF 24': {'sections': ['A', 'B', 'C']}}

# %% [markdown]
# ### 2.2
#
# The second report the Registrar needs is a _class list_ of every section. They want this report in the form of a **dictionary** whose keys are the course code and whose values are dictionaries describing the sections of that course code. Each section dictionary has two key-value pairs:
# 1. Key: "section"; Value: Section letter
# 2. Key: "class list"; Value: [id numbers]
#
# Here is the schema of the desired output:
# `{`
# &nbsp;&nbsp;&nbsp;&nbsp;`course_code: [{`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"section": section_letter,`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"class list": [id_numbers]`
# &nbsp;&nbsp;&nbsp;&nbsp;`}]`
# `}`
#
# A dictionary called `class_lists` is provided to you. Using `student_data`, populate `class_lists` with the data that the Registrar needs.
#
# Dump this file as `./output/class-lists.json`.
#
# Additional specifications:
# 1. Sort the list of ID numbers. No need to convert them to int, just sort them in place with `.sort()`.
# 2. Do not reference the `courses` dictionary from Item 2.1 directly. This cell should be able to run independently of Item 2.1. You may, however, reuse your code by copy-pasting it here if you find that it will help.
#
# Sample output is provided in `./section2/class-lists-sample-output.json`.

# %%
# CODE CELL
import json
class_lists = {}

# CODE START

course_list = []

for i in range(len(student_data)):
    for j in range(len(student_data[i]["enlistment"])):
        course_list.append(student_data[i]["enlistment"][j]["course code"])

    
course_list = list(set(course_list))
course_list.sort()
 

for z in course_list:
    class_lists.update({z:[]})
    section = []
    for x in range(len(student_data)):
        for y in range(len(student_data[x]["enlistment"])):
            if student_data[x]["enlistment"][y]["course code"] == z:
                section.append(student_data[x]["enlistment"][y]["section"])
    section = list(set(section))
    section.sort()

    for a in section:
        idnum = []
        for b in range(len(student_data)):
            for c in range(len(student_data[b]["enlistment"])):
                if student_data[b]["enlistment"][c]["section"] == a and student_data[b]["enlistment"][c]["course code"] == z:
                    idnum.append(student_data[b]["id"])
        idnum = list(set(idnum))
        idnum.sort()


        class_lists[z].append({"section" : a, "class list" : idnum})

with open('./output/class-lists.json','w') as jsonfile:
    json.dump(class_lists,jsonfile)

class_lists

# CODE END

# The output should look like this.
# This code is not supposed to be able to run in your notebook; it is fine to remove it if you will begin working.
# Out:
# {'AI 41': [{'section': 'A',
#    'class list': ['201042',
#     '201121',
#     '201246',
#     '201311',
#     '201371',
#     '201459',
#     '201467',
#     '201724',
#     '201736',
#     '201969',
#     '202352',
#     '202372',
#     '202396',
#     '202398',
#     '202572',
#     '202582',
#     '202750',
#     '202916',
#     '202952',
#     '202973',
#     '203021',
#     '203063',
#     '203107',
#     '203164',
#     '203205',
#     '203206',
#     '203301',
#     '203340',
#     '203397',
#     '203430',
#     '203444',
#     '203477',
#     '203478',
#     '203519',
#     '203537',
#     '203577',
#     '203619',
#     '203756',
#     '204018',
#     '204287',
#     '204325',
#     '204387',
#     '204518',
#     '204574',
#     '204640',
#     '204787',
#     '204927',
#     '205066',
#     '205079',
#     '205086',
#     '205218',
#     '205263',
#     '205283',
#     '205325',
#     '205383',
#     '211120',
#     '211141',
#     '211196',
#     '211205',
#     '211219',
#     '211300',
#     '211324',
#     '211453',
#     '211492',
#     '211549',
#     '211740',
#     '211812',
#     '211934',
#     '212100',
#     '212124',
#     '212131',
#     '212241',
#     '212300',
#     '212318',
#     '212481',
#     '212511',
#     '212745',
#     '212760',
#     '212788',
#     '212936',
#     '213062',
#     '213381',
#     '213744',
#     '213768',
#     '213794',
#     '213888',
#     '214058',
#     '214091',
#     '214096',
#     '214190',
#     '214545',
#     '214599',
#     '214710',
#     '214741',
#     '214991',
#     '215078',
#     '215082',
#     '215083',
#     '215124',
#     '215163',
#     '215374',
#     '215398']},
#   {'section': 'B',
#    'class list': ['201078',
#     '201239',
#     '201330',
#     '201396',
#     '201471',
#     '201542',
#     '201595',
#     '201685',
#     '201714',
#     '201731',
#     '201766',
#     '201802',
#     '202127',
#     '202271',
#     '202530',
#     '202571',
#     '202575',
#     '202806',
#     '203000',
#     '203027',
#     '203037',
#     '203186',
#     '203231',
#     '203350',
#     '203506',
#     '203586',
#     '203823',
#     '203893',
#     '203903',
#     '203970',
#     '204068',
#     '204177',
#     '204207',
#     '204274',
#     '204286',
#     '204567',
#     '204664',
#     '204683',
#     '204685',
#     '204867',
#     '204898',
#     '205090',
#     '205253',
#     '205269',
#     '205304',
#     '205338',
#     '211060',
#     '211149',
#     '211207',
#     '211232',
#     '211233',
#     '211252',
#     '211253',
#     '211264',
#     '211314',
#     '211328',
#     '211447',
#     '211644',
#     '211718',
#     '211726',
#     '211733',
#     '211745',
#     '211956',
#     '211981',
#     '211999',
#     '212018',
#     '212062',
#     '212086',
#     '212111',
#     '212142',
#     '212242',
#     '212323',
#     '212385',
#     '212390',
#     '212489',
#     '212565',
#     '212594',
#     '212641',
#     '212692',
#     '212830',
#     '213026',
#     '213077',
#     '213360',
#     '213374',
#     '213451',
#     '213582',
#     '213641',
#     '213852',
#     '214422',
#     '214430',
#     '214694',
#     '214705',
#     '214716',
#     '214959',
#     '214989',
#     '215029',
#     '215051',
#     '215064',
#     '215306',
#     '215333',
#     '215403']},
#   {'section': 'C',
#    'class list': ['201077',
#     '201117',
#     '201178',
#     '201343',
#     '201481',
#     '201615',
#     '201722',
#     '201767',
#     '201911',
#     '201980',
#     '202036',
#     '202082',
#     '202103',
#     '202203',
#     '202213',
#     '202275',
#     '202387',
#     '202545',
#     '202568',
#     '202583',
#     '202762',
#     '202949',
#     '203009',
#     '203237',
#     '203528',
#     '203572',
#     '203676',
#     '203684',
#     '203730',
#     '203874',
#     '203911',
#     '203999',
#     '204051',
#     '204242',
#     '204277',
#     '204401',
#     '204425',
#     '204426',
#     '204531',
#     '204844',
#     '204897',
#     '205009',
#     '205042',
#     '205164',
#     '205299',
#     '211283',
#     '211315',
#     '211329',
#     '211373',
#     '211437',
#     '211637',
#     '211665',
#     '211754',
#     '211847',
#     '211864',
#     '211940',
#     '211959',
#     '211996',
#     '212069',
#     '212101',
#     '212183',
#     '212229',
#     '212304',
#     '212377',
#     '212709',
#     '212712',
#     '212800',
#     '212833',
#     '212935',
#     '213066',
#     '213069',
#     '213415',
#     '213448',
#     '213470',
#     '213507',
#     '213592',
#     '213660',
#     '213717',
#     '213727',
#     '213770',
#     '213815',
#     '213960',
#     '213994',
#     '214100',
#     '214103',
#     '214104',
#     '214137',
#     '214517',
#     '214563',
#     '214605',
#     '214681',
#     '214727',
#     '214729',
#     '215001',
#     '215024',
#     '215128',
#     '215243',
#     '215350',
#     '215391']},
#   {'section': 'D',
#    'class list': ['201095',
#     '201146',
#     '201363',
#     '201519',
#     '201570',
#     '201669',
#     '201684',
#     '201833',
#     '201868',
#     '201926',
#     '201983',
#     '202324',
#     '202559',
#     '202577',
#     '202592',
#     '202647',
#     '202652',
#     '203104',
#     '203144',
#     '203349',
#     '203508',
#     '203632',
#     '203649',
#     '203688',
#     '203719',
#     '203813',
#     '203951',
#     '204023',
#     '204040',
#     '204076',
#     '204140',
#     '204263',
#     '204326',
#     '204355',
#     '204389',
#     '204416',
#     '204417',
#     '204439',
#     '204535',
#     '204746',
#     '204812',
#     '204891',
#     '204947',
#     '205155',
#     '205162',
#     '205190',
#     '205202',
#     '205318',
#     '205324',
#     '205402',
#     '211015',
#     '211071',
#     '211167',
#     '211188',
#     '211547',
#     '211552',
#     '211599',
#     '211654',
#     '211781',
#     '211928',
#     '211943',
#     '211970',
#     '212116',
#     '212401',
#     '212424',
#     '212488',
#     '212610',
#     '212630',
#     '212684',
#     '212841',
#     '212891',
#     '213122',
#     '213241',
#     '213376',
#     '213387',
#     '213584',
#     '213950',
#     '214017',
#     '214295',
#     '214347',
#     '214385',
#     '214480',
#     '214592',
#     '214704',
#     '214792',
#     '214836',
#     '214904',
#     '215095',
#     '215174',
#     '215255',
#     '215410']},
#   {'section': 'E',
#    'class list': ['201018',
#     '201032',
#     '201044',
#     '201129',
#     '201172',
#     '201359',
#     '201457',
#     '201482',
#     '201543',
#     '201560',
#     '201653',
#     '201822',
#     '202026',
#     '202230',
#     '202317',
#     '202596',
#     '202606',
#     '202636',
#     '202748',
#     '203082',
#     '203171',
#     '203193',
#     '203195',
#     '203248',
#     '203308',
#     '203354',
#     '203434',
#     '203618',
#     '203827',
#     '203894',
#     '204323',
#     '204354',
#     '204413',
#     '204618',
#     '204631',
#     '204662',
#     '204829',
#     '204987',
#     '205134',
#     '211157',
#     '211243',
#     '211345',
#     '211529',
#     '211572',
#     '211612',
#     '211748',
#     '211844',
#     '211950',
#     '212081',
#     '212118',
#     '212185',
#     '212273',
#     '212434',
#     '212553',
#     '212589',
#     '212637',
#     '212723',
#     '212780',
#     '212870',
#     '212919',
#     '212920',
#     '212924',
#     '212953',
#     '212979',
#     '213007',
#     '213074',
#     '213268',
#     '213363',
#     '213393',
#     '213489',
#     '213525',
#     '213573',
#     '213636',
#     '213650',
#     '213677',
#     '213830',
#     '213878',
#     '214045',
#     '214193',
#     '214200',
#     '214311',
#     '214467',
#     '214534',
#     '214555',
#     '214724',
#     '214929',
#     '214968',
#     '215022',
#     '215125',
#     '215199',
#     '215321',
#     '215370']}],
#  'AX 43': [{'section': 'A',
#    'class list': ['201032',
#     '201050',
#     '201067',
#     '201070',
#     '201072',
#     '201086',
#     '201103',
#     '201116',
#     '201140',
#     '201156',
#     '201170',
#     '201178',
#     '201191',
#     '201195',
#     '201197',
#     '201213',
#     '201224',
#     '201272',
#     '201282',
#     '201309',
#     '201355',
#     '201356',
#     '201375',
#     '201382',
#     '201416',
#     '201418',
#     '201462',
#     '201473',
#     '201474',
#     '201486',
#     '201502',
#     '201551',
#     '201563',
#     '201571',
#     '201597',
#     '201604',
#     '201607',
#     '201662',
#     '201668',
#     '201673',
#     '201681',
#     '201684',
#     '201696',
#     '201710',
#     '201715',
#     '201720',
#     '201772',
#     '201780',
#     '201790',
#     '201819',
#     '201826',
#     '201834',
#     '201841',
#     '201869',
#     '201879',
#     '201893',
#     '201896',
#     '201914',
#     '201924',
#     '201926',
#     '201963',
#     '201964',
#     '201974',
#     '201997',
#     '202002',
#     '202022',
#     '202026',
#     '202061',
#     '202063',
#     '202078',
#     '202092',
#     '202143',
#     '202154',
#     '202161',
#     '202201',
#     '202203',
#     '202231',
#     '202234',
#     '202272',
#     '202283',
#     '202290',
#     '202293',
#     '202311',
#     '202312',
#     '202326',
#     '202329',
#     '202331',
#     '202349',
#     '202363',
#     '202369',
#     '202372',
#     '202408',
#     '202418',
#     '202423',
#     '202430',
#     '202438',
#     '202457',
#     '202473',
#     '202474',
#     '202512',
#     '202514',
#     '202526',
#     '202528',
#     '202554',
#     '202568',
#     '202572',
#     '202605',
#     '202645',
#     '202657',
#     '202683',
#     '202739',
#     '202748',
#     '202794',
#     '202801',
#     '202827',
#     '202844',
#     '202871',
#     '202875',
#     '202887',
#     '202894',
#     '202902',
#     '202944',
#     '202967',
#     '202975',
#     '202977',
#     '202980',
#     '203010',
#     '203021',
#     '203045',
#     '203056',
#     '203100',
#     '203135',
#     '203142',
#     '203167',
#     '203177',
#     '203217',
#     '203233',
#     '203239',
#     '203278',
#     '203297',
#     '203298',
#     '203299',
#     '203308',
#     '203311',
#     '203317',
#     '203353',
#     '203365',
#     '203383',
#     '203410',
#     '203416',
#     '203473',
#     '203506',
#     '203511',
#     '203529',
#     '203538',
#     '203543',
#     '203544',
#     '203577',
#     '203580',
#     '203610',
#     '203632',
#     '203645',
#     '203649',
#     '203657',
#     '203667',
#     '203702',
#     '203743',
#     '203754',
#     '203805',
#     '203832',
#     '203839',
#     '203862',
#     '203874',
#     '203876',
#     '203877',
#     '203900',
#     '203907',
#     '203912',
#     '203919',
#     '203968',
#     '203991',
#     '204004',
#     '204021',
#     '204034',
#     '204036',
#     '204051',
#     '204093',
#     '204117',
#     '204140',
#     '204152',
#     '204185',
#     '204194',
#     '204199',
#     '204224',
#     '204235',
#     '204245',
#     '204253',
#     '204266',
#     '204269',
#     '204304',
#     '204316',
#     '204320',
#     '204326',
#     '204387',
#     '204388',
#     '204395',
#     '204406',
#     '204419',
#     '204437',
#     '204490',
#     '204502',
#     '204541',
#     '204569',
#     '204585',
#     '204596',
#     '204598',
#     '204617',
#     '204642',
#     '204676',
#     '204695',
#     '204702',
#     '204715',
#     '204728',
#     '204737',
#     '204739',
#     '204761',
#     '204764',
#     '204805',
#     '204815',
#     '204829',
#     '204871',
#     '204883',
#     '204884',
#     '204897',
#     '204914',
#     '204926',
#     '204978',
#     '204995',
#     '204999',
#     '205013',
#     '205015',
#     '205028',
#     '205034',
#     '205042',
#     '205054',
#     '205056',
#     '205059',
#     '205097',
#     '205134',
#     '205136',
#     '205173',
#     '205185',
#     '205208',
#     '205276',
#     '205283',
#     '205301',
#     '205304',
#     '205319',
#     '205343',
#     '205376',
#     '205377',
#     '205389',
#     '205407',
#     '211016',
#     '211027',
#     '211033',
#     '211046',
#     '211054',
#     '211059',
#     '211075',
#     '211131',
#     '211154',
#     '211166',
#     '211167',
#     '211169',
#     '211181',
#     '211192',
#     '211199',
#     '211201',
#     '211207',
#     '211208',
#     '211217',
#     '211266',
#     '211284',
#     '211322',
#     '211325',
#     '211328',
#     '211338',
#     '211344',
#     '211346',
#     '211353',
#     '211360',
#     '211367',
#     '211368',
#     '211380',
#     '211387',
#     '211394',
#     '211401',
#     '211406',
#     '211407',
#     '211420',
#     '211438',
#     '211444',
#     '211452',
#     '211461',
#     '211468',
#     '211475',
#     '211483',
#     '211484',
#     '211489',
#     '211522',
#     '211530',
#     '211541',
#     '211547',
#     '211575',
#     '211614',
#     '211628',
#     '211641',
#     '211647',
#     '211658',
#     '211664',
#     '211728',
#     '211758',
#     '211794',
#     '211816',
#     '211844',
#     '211862',
#     '211865',
#     '211908',
#     '211913',
#     '211919',
#     '211932',
#     '211942',
#     '211943',
#     '211950',
#     '211960',
#     '211985',
#     '212010',
#     '212030',
#     '212047',
#     '212064',
#     '212094',
#     '212107',
#     '212112',
#     '212122',
#     '212124',
#     '212156',
#     '212170',
#     '212186',
#     '212190',
#     '212194',
#     '212215',
#     '212287',
#     '212289',
#     '212302',
#     '212309',
#     '212334',
#     '212367',
#     '212390',
#     '212412',
#     '212439',
#     '212440',
#     '212449',
#     '212475',
#     '212511',
#     '212561',
#     '212581',
#     '212602',
#     '212630',
#     '212640',
#     '212667',
#     '212672',
#     '212678',
#     '212687',
#     '212702',
#     '212747',
#     '212754',
#     '212793',
#     '212809',
#     '212813',
#     '212819',
#     '212842',
#     '212845',
#     '212858',
#     '212882',
#     '212900',
#     '212906',
#     '212907',
#     '212917',
#     '212926',
#     '212937',
#     '212938',
#     '212945',
#     '212958',
#     '212961',
#     '212965',
#     '213007',
#     '213029',
#     '213047',
#     '213057',
#     '213088',
#     '213089',
#     '213094',
#     '213098',
#     '213108',
#     '213146',
#     '213160',
#     '213226',
#     '213253',
#     '213275',
#     '213279',
#     '213326',
#     '213363',
#     '213381',
#     '213385',
#     '213401',
#     '213433',
#     '213436',
#     '213441',
#     '213459',
#     '213464',
#     '213475',
#     '213490',
#     '213494',
#     '213496',
#     '213501',
#     '213549',
#     '213553',
#     '213563',
#     '213574',
#     '213598',
#     '213626',
#     '213663',
#     '213674',
#     '213687',
#     '213699',
#     '213700',
#     '213750',
#     '213788',
#     '213797',
#     '213803',
#     '213820',
#     '213861',
#     '213886',
#     '213910',
#     '213923',
#     '213948',
#     '213955',
#     '213960',
#     '213995',
#     '213996',
#     '214007',
#     '214017',
#     '214020',
#     '214031',
#     '214072',
#     '214090',
#     '214101',
#     '214114',
#     '214124',
#     '214150',
#     '214157',
#     '214182',
#     '214197',
#     '214209',
#     '214261',
#     '214268',
#     '214270',
#     '214295',
#     '214297',
#     '214302',
#     '214306',
#     '214313',
#     '214341',
#     '214351',
#     '214357',
#     '214370',
#     '214374',
#     '214446',
#     '214451',
#     '214475',
#     '214477',
#     '214507',
#     '214510',
#     '214526',
#     '214532',
#     '214536',
#     '214537',
#     '214674',
#     '214680',
#     '214688',
#     '214699',
#     '214716',
#     '214723',
#     '214741',
#     '214769',
#     '214794',
#     '214801',
#     '214804',
#     '214806',
#     '214850',
#     '214952',
#     '214982',
#     '214988',
#     '214991',
#     '215001',
#     '215006',
#     '215011',
#     '215014',
#     '215029',
#     '215030',
#     '215044',
#     '215068',
#     '215076',
#     '215083',
#     '215092',
#     '215107',
#     '215128',
#     '215143',
#     '215158',
#     '215207',
#     '215213',
#     '215216',
#     '215220',
#     '215224',
#     '215240',
#     '215268',
#     '215273',
#     '215285',
#     '215306',
#     '215334',
#     '215367',
#     '215371',
#     '215399',
#     '215406']}],
#  'BN 85': [{'section': 'A',
#    'class list': ['201058',
#     '201153',
#     '201183',
#     '201248',
#     '201371',
#     '201375',
#     '201404',
#     '201462',
#     '201521',
#     '201525',
#     '201609',
#     '201763',
#     '202103',
#     '202274',
#     '202551',
#     '202560',
#     '202573',
#     '202794',
#     '202831',
#     '202850',
#     '202949',
#     '203312',
#     '203383',
#     '203405',
#     '203529',
#     '203589',
#     '203702',
#     '203901',
#     '203959',
#     '204084',
#     '204089',
#     '204339',
#     '204404',
#     '204419',
#     '204424',
#     '204658',
#     '204846',
#     '204927',
#     '204998',
#     '205060',
#     '205295',
#     '205296',
#     '205317',
#     '205343',
#     '205389',
#     '211030',
#     '211059',
#     '211120',
#     '211302',
#     '211466',
#     '211610',
#     '211614',
#     '211660',
#     '211862',
#     '211943',
#     '212120',
#     '212193',
#     '212288',
#     '212367',
#     '212489',
#     '212656',
#     '212771',
#     '213169',
#     '213191',
#     '213525',
#     '213588',
#     '213647',
#     '213726',
#     '213788',
#     '213826',
#     '213868',
#     '213930',
#     '213987',
#     '214146',
#     '214182',
#     '214319',
#     '214386',
#     '214480',
#     '214492',
#     '214497',
#     '214507',
#     '214558',
#     '214581',
#     '214930',
#     '215131',
#     '215193',
#     '215237',
#     '215262',
#     '215281',
#     '215297',
#     '215348']},
#   {'section': 'B',
#    'class list': ['201129',
#     '201225',
#     '201423',
#     '201567',
#     '201694',
#     '201891',
#     '201990',
#     '202036',
#     '202310',
#     '202360',
#     '202464',
#     '202497',
#     '202514',
#     '202569',
#     '202606',
#     '202619',
#     '202767',
#     '202950',
#     '202966',
#     '203012',
#     '203167',
#     '203187',
#     '203246',
#     '203418',
#     '203521',
#     '203587',
#     '203752',
#     '203810',
#     '203952',
#     '204085',
#     '204093',
#     '204189',
#     '204224',
#     '204618',
#     '204645',
#     '204737',
#     '204935',
#     '205190',
#     '205239',
#     '205323',
#     '211011',
#     '211091',
#     '211276',
#     '211465',
#     '211497',
#     '211558',
#     '211618',
#     '211640',
#     '211760',
#     '211791',
#     '211840',
#     '211908',
#     '211936',
#     '211962',
#     '212105',
#     '212448',
#     '212601',
#     '212610',
#     '212667',
#     '212782',
#     '212814',
#     '212947',
#     '213005',
#     '213116',
#     '213150',
#     '213481',
#     '213489',
#     '213643',
#     '213682',
#     '213700',
#     '213785',
#     '213786',
#     '213808',
#     '213883',
#     '213899',
#     '214075',
#     '214083',
#     '214102',
#     '214184',
#     '214214',
#     '214392',
#     '214410',
#     '214431',
#     '214446',
#     '214495',
#     '214629',
#     '214752',
#     '215027',
#     '215095',
#     '215128',
#     '215395']},
#   {'section': 'C',
#    'class list': ['201005',
#     '201029',
#     '201085',
#     '201347',
#     '201592',
#     '201595',
#     '201907',
#     '201949',
#     '202216',
#     '202290',
#     '202329',
#     '202335',
#     '202486',
#     '202585',
#     '202632',
#     '202652',
#     '202666',
#     '202791',
#     '202826',
#     '203059',
#     '203164',
#     '203483',
#     '203511',
#     '203654',
#     '203678',
#     '203680',
#     '203740',
#     '203862',
#     '203875',
#     '203927',
#     '204012',
#     '204118',
#     '204234',
#     '204269',
#     '204314',
#     '204491',
#     '204606',
#     '204711',
#     '204793',
#     '204911',
#     '204923',
#     '204983',
#     '205164',
#     '205214',
#     '205301',
#     '205386',
#     '211012',
#     '211041',
#     '211180',
#     '211193',
#     '211223',
#     '211420',
#     '211447',
#     '211483',
#     '211537',
#     '211637',
#     '211748',
#     '211794',
#     '211890',
#     '211998',
#     '212023',
#     '212148',
#     '212210',
#     '212219',
#     '212256',
#     '212297',
#     '212305',
#     '212475',
#     '212490',
#     '212500',
#     '212564',
#     '212618',
#     '212836',
#     '212886',
#     '212948',
#     '213162',
#     '213203',
#     '213227',
#     '213232',
#     '213367',
#     '213449',
#     '213507',
#     '213650',
#     '213665',
#     '213694',
#     '213776',
#     '213873',
#     '214026',
#     '214209',
#     '214422',
#     '214501',
#     '214583',
#     '214678',
#     '214771',
#     '214784',
#     '214795',
#     '214877',
#     '214988',
#     '215057',
#     '215148',
#     '215172',
#     '215367',
#     '215379']},
#   {'section': 'D',
#    'class list': ['201049',
#     '201077',
#     '201515',
#     '201833',
#     '201966',
#     '202338',
#     '202387',
#     '202530',
#     '202620',
#     '202639',
#     '202645',
#     '202715',
#     '202987',
#     '203040',
#     '203144',
#     '203190',
#     '203262',
#     '203300',
#     '203402',
#     '203474',
#     '203912',
#     '203983',
#     '203991',
#     '204139',
#     '204292',
#     '204343',
#     '204395',
#     '204442',
#     '204448',
#     '204697',
#     '204730',
#     '204749',
#     '204758',
#     '204860',
#     '205275',
#     '211100',
#     '211123',
#     '211256',
#     '211540',
#     '211608',
#     '211628',
#     '211878',
#     '211905',
#     '211986',
#     '212027',
#     '212065',
#     '212226',
#     '212287',
#     '212308',
#     '212342',
#     '212343',
#     '212395',
#     '212685',
#     '212712',
#     '212717',
#     '212772',
#     '212804',
#     '212874',
#     '213011',
#     '213133',
#     '213219',
#     '213361',
#     '213417',
#     '213490',
#     '213504',
#     '213669',
#     '213681',
#     '213727',
#     '213923',
#     '213932',
#     '213992',
#     '214055',
#     '214058',
#     '214067',
#     '214071',
#     '214358',
#     '214398',
#     '214415',
#     '214738',
#     '214803',
#     '214859',
#     '214869',
#     '214889',
#     '214912',
#     '215093',
#     '215114']},
#   {'section': 'E',
#    'class list': ['201144',
#     '201172',
#     '201306',
#     '201350',
#     '201459',
#     '201569',
#     '201603',
#     '201646',
#     '201730',
#     '201743',
#     '201887',
#     '202038',
#     '202331',
#     '202362',
#     '202588',
#     '202695',
#     '202750',
#     '202768',
#     '202876',
#     '202892',
#     '202896',
#     '202952',
#     '202988',
#     '203147',
#     '203186',
#     '203188',
#     '203230',
#     '203298',
#     '203394',
#     '203409',
#     '203422',
#     '203586',
#     '203597',
#     '203608',
#     '203644',
#     '203719',
#     '203864',
#     '204342',
#     '204348',
#     '204630',
#     '204805',
#     '204828',
#     '204833',
#     '204845',
#     '204897',
#     '204909',
#     '204915',
#     '204987',
#     '205036',
#     '205117',
#     '205119',
#     '205204',
#     '211021',
#     '211097',
#     '211134',
#     '211173',
#     '211182',
#     '211207',
#     '211296',
#     '211313',
#     '211346',
#     '211394',
#     '211680',
#     '211770',
#     '211808',
#     '211921',
#     '211928',
#     '211932',
#     '212178',
#     '212180',
#     '212196',
#     '212225',
#     '212289',
#     '212323',
#     '212602',
#     '212684',
#     '212755',
#     '212788',
#     '212819',
#     '212979',
#     '213220',
#     '213352',
#     '213370',
#     '213448',
#     '213503',
#     '213591',
#     '213598',
#     '213822',
#     '213861',
#     '213942',
#     '214038',
#     '214227',
#     '214515',
#     '214579',
#     '214644',
#     '214675',
#     '214718',
#     '214933',
#     '214991',
#     '215068',
#     '215076',
#     '215120',
#     '215229',
#     '215243',
#     '215397']},
#   {'section': 'F',
#    'class list': ['201068',
#     '201072',
#     '201118',
#     '201191',
#     '201307',
#     '201511',
#     '201513',
#     '201570',
#     '201880',
#     '201976',
#     '202019',
#     '202076',
#     '202149',
#     '202394',
#     '202460',
#     '202708',
#     '202746',
#     '202862',
#     '202884',
#     '203041',
#     '203168',
#     '203316',
#     '203416',
#     '203425',
#     '203599',
#     '203667',
#     '203741',
#     '203809',
#     '203907',
#     '204215',
#     '204287',
#     '204325',
#     '204486',
#     '204506',
#     '204633',
#     '204835',
#     '204918',
#     '205136',
#     '205177',
#     '205253',
#     '205263',
#     '205304',
#     '205339',
#     '205340',
#     '211034',
#     '211128',
#     '211209',
#     '211546',
#     '211552',
#     '211647',
#     '211651',
#     '211656',
#     '211803',
#     '211818',
#     '211931',
#     '211939',
#     '212017',
#     '212595',
#     '212644',
#     '212707',
#     '212766',
#     '212953',
#     '213089',
#     '213112',
#     '213228',
#     '213359',
#     '213457',
#     '213488',
#     '213545',
#     '213549',
#     '213576',
#     '214105',
#     '214143',
#     '214186',
#     '214206',
#     '214264',
#     '214573',
#     '214593',
#     '214669',
#     '214671',
#     '214740',
#     '214756',
#     '214806',
#     '215355']}],
#  'EN 94': [{'section': 'A',
#    'class list': ['201068',
#     '201076',
#     '201084',
#     '201090',
#     '201104',
#     '201279',
#     '201334',
#     '201339',
#     '201366',
#     '201439',
#     '201471',
#     '201531',
#     '201563',
#     '201591',
#     '201743',
#     '201752',
#     '201976',
#     '201994',
#     '201997',
#     '202150',
#     '202456',
#     '202513',
#     '202531',
#     '202790',
#     '202796',
#     '202823',
#     '203131',
#     '203217',
#     '203317',
#     '203871',
#     '203877',
#     '203892',
#     '203900',
#     '204048',
#     '204117',
#     '204128',
#     '204144',
#     '204228',
#     '204287',
#     '204405',
#     '204531',
#     '204880',
#     '204914',
#     '204966',
#     '205123',
#     '205211',
#     '205214',
#     '205276',
#     '205318',
#     '205338',
#     '211031',
#     '211112',
#     '211215',
#     '211322',
#     '211432',
#     '211672',
#     '211820',
#     '212110',
#     '212152',
#     '212342',
#     '212351',
#     '212401',
#     '212522',
#     '212668',
#     '212694',
#     '212797',
#     '212853',
#     '212945',
#     '212978',
#     '212992',
#     '213222',
#     '213560',
#     '213596',
#     '213636',
#     '213795',
#     '213953',
#     '214005',
#     '214641',
#     '214790',
#     '215193',
#     '215331']},
#   {'section': 'B',
#    'class list': ['201001',
#     '201294',
#     '201727',
#     '201731',
#     '202243',
#     '202254',
#     '202281',
#     '202393',
#     '202479',
#     '202575',
#     '202654',
#     '202657',
#     '202711',
#     '202776',
#     '203416',
#     '203439',
#     '203602',
#     '203802',
#     '203957',
#     '203962',
#     '204106',
#     '204575',
#     '204683',
#     '204697',
#     '204702',
#     '204853',
#     '204881',
#     '205239',
#     '205294',
#     '211109',
#     '211258',
#     '211298',
#     '211368',
#     '211387',
#     '211498',
#     '211517',
#     '211599',
#     '211650',
#     '211870',
#     '211877',
#     '211939',
#     '211956',
#     '211962',
#     '212109',
#     '212111',
#     '212170',
#     '212182',
#     '212210',
#     '212229',
#     '212245',
#     '212437',
#     '212540',
#     '212728',
#     '212734',
#     '212943',
#     '213007',
#     '213095',
#     '213098',
#     '213109',
#     '213174',
#     '213211',
#     '213244',
#     '213291',
#     '213295',
#     '213367',
#     '213807',
#     '213898',
#     '214182',
#     '214374',
#     '214399',
#     '214735',
#     '214859',
#     '214941',
#     '214957',
#     '214974',
#     '215196',
#     '215305',
#     '215354']},
#   {'section': 'C',
#    'class list': ['201082',
#     '201121',
#     '201254',
#     '201330',
#     '201416',
#     '201480',
#     '201607',
#     '201617',
#     '201648',
#     '201649',
#     '201693',
#     '201706',
#     '202038',
#     '202061',
#     '202071',
#     '202298',
#     '202303',
#     '202551',
#     '202566',
#     '202690',
#     '202722',
#     '202865',
#     '203021',
#     '203091',
#     '203159',
#     '203161',
#     '203205',
#     '203237',
#     '203247',
#     '203269',
#     '203345',
#     '203358',
#     '203395',
#     '203624',
#     '203638',
#     '203766',
#     '203849',
#     '203865',
#     '204359',
#     '204565',
#     '204976',
#     '205008',
#     '205362',
#     '211190',
#     '211193',
#     '211228',
#     '211230',
#     '211286',
#     '211659',
#     '211913',
#     '212057',
#     '212212',
#     '212427',
#     '212579',
#     '212727',
#     '212744',
#     '212771',
#     '213126',
#     '213140',
#     '213241',
#     '213324',
#     '213443',
#     '213562',
#     '213582',
#     '213648',
#     '213855',
#     '214007',
#     '214037',
#     '214090',
#     '214114',
#     '214200',
#     '214202',
#     '214351',
#     '214418',
#     '214438',
#     '214474',
#     '214593',
#     '214736',
#     '214955',
#     '215022',
#     '215023',
#     '215175',
#     '215231',
#     '215409']},
#   {'section': 'D',
#    'class list': ['201007',
#     '201305',
#     '201623',
#     '201646',
#     '201875',
#     '201991',
#     '202063',
#     '202218',
#     '202380',
#     '202527',
#     '202569',
#     '202663',
#     '202726',
#     '202952',
#     '202989',
#     '203115',
#     '203117',
#     '203302',
#     '203569',
#     '203656',
#     '203753',
#     '203836',
#     '203856',
#     '203911',
#     '204028',
#     '204044',
#     '204068',
#     '204188',
#     '204220',
#     '204332',
#     '204366',
#     '204407',
#     '204608',
#     '204613',
#     '204700',
#     '204728',
#     '204787',
#     '204861',
#     '204879',
#     '204953',
#     '204964',
#     '205087',
#     '205103',
#     '205372',
#     '205408',
#     '211034',
#     '211047',
#     '211060',
#     '211930',
#     '212033',
#     '212086',
#     '212097',
#     '212219',
#     '212508',
#     '212561',
#     '212633',
#     '212687',
#     '212704',
#     '212709',
#     '212907',
#     '212954',
#     '213002',
#     '213275',
#     '213674',
#     '213697',
#     '213815',
#     '213851',
#     '213869',
#     '214064',
#     '214073',
#     '214161',
#     '214217',
#     '214481',
#     '214499',
#     '214584',
#     '214586',
#     '214680',
#     '214826',
#     '214874',
#     '214931',
#     '214990',
#     '215057']},
#   {'section': 'E',
#    'class list': ['201115',
#     '201239',
#     '201278',
#     '201320',
#     '201488',
#     '201502',
#     '201516',
#     '201857',
#     '201968',
#     '202060',
#     '202257',
#     '202403',
#     '202419',
#     '203100',
#     '203271',
#     '203422',
#     '203550',
#     '203555',
#     '203616',
#     '203625',
#     '203679',
#     '203748',
#     '203767',
#     '203897',
#     '203968',
#     '204019',
#     '204041',
#     '204053',
#     '204580',
#     '204822',
#     '205180',
#     '205228',
#     '205296',
#     '211054',
#     '211196',
#     '211217',
#     '211234',
#     '211259',
#     '211302',
#     '211353',
#     '211534',
#     '211840',
#     '211989',
#     '212332',
#     '212384',
#     '212413',
#     '212674',
#     '212742',
#     '212870',
#     '212873',
#     '212933',
#     '213252',
#     '213396',
#     '213510',
#     '213553',
#     '213576',
#     '213812',
#     '213842',
#     '214197',
#     '214251',
#     '214288',
#     '214391',
#     '214410',
#     '214462',
#     '214554',
#     '214600',
#     '214646',
#     '214801',
#     '214887',
#     '214969',
#     '214973',
#     '215052',
#     '215143',
#     '215270',
#     '215346',
#     '215374',
#     '215398']},
#   {'section': 'F',
#    'class list': ['201039',
#     '201052',
#     '201080',
#     '201135',
#     '201198',
#     '201382',
#     '201564',
#     '201621',
#     '201724',
#     '201747',
#     '201897',
#     '202059',
#     '202067',
#     '202157',
#     '202160',
#     '202251',
#     '202324',
#     '202357',
#     '202430',
#     '202436',
#     '202445',
#     '202526',
#     '202653',
#     '202763',
#     '202872',
#     '202964',
#     '203033',
#     '203080',
#     '203266',
#     '203405',
#     '203434',
#     '203438',
#     '203589',
#     '203604',
#     '203862',
#     '203895',
#     '204317',
#     '204666',
#     '204676',
#     '204821',
#     '204876',
#     '205150',
#     '205167',
#     '205210',
#     '205267',
#     '205269',
#     '205282',
#     '205342',
#     '205368',
#     '211136',
#     '211247',
#     '211268',
#     '211620',
#     '211950',
#     '211992',
#     '212196',
#     '212321',
#     '212443',
#     '212505',
#     '212673',
#     '212725',
#     '212808',
#     '212824',
#     '212923',
#     '212935',
#     '213124',
#     '213292',
#     '213305',
#     '213318',
#     '213390',
#     '213431',
#     '213958',
#     '213960',
#     '214092',
#     '214423',
#     '214488',
#     '214557',
#     '214581',
#     '214649',
#     '214855',
#     '214980',
#     '215184',
#     '215215',
#     '215300',
#     '215399',
#     '215400']}],
#  'EQ 61': [{'section': 'A',
#    'class list': ['201043',
#     '201073',
#     '201143',
#     '201287',
#     '201481',
#     '201570',
#     '201592',
#     '201597',
#     '201615',
#     '201677',
#     '201744',
#     '201899',
#     '201914',
#     '201922',
#     '201966',
#     '201971',
#     '201980',
#     '201990',
#     '202021',
#     '202073',
#     '202181',
#     '202283',
#     '202575',
#     '202607',
#     '202617',
#     '202775',
#     '202777',
#     '202794',
#     '202847',
#     '202913',
#     '202976',
#     '203035',
#     '203037',
#     '203309',
#     '203575',
#     '203633',
#     '203692',
#     '203733',
#     '203751',
#     '203813',
#     '203922',
#     '203933',
#     '204168',
#     '204275',
#     '204379',
#     '204414',
#     '204572',
#     '204585',
#     '204630',
#     '204639',
#     '204661',
#     '204709',
#     '204793',
#     '204799',
#     '204818',
#     '204950',
#     '205005',
#     '205013',
#     '205036',
#     '205176',
#     '205187',
#     '205197',
#     '205209',
#     '205211',
#     '205233',
#     '205332',
#     '211036',
#     '211041',
#     '211057',
#     '211075',
#     '211106',
#     '211113',
#     '211127',
#     '211175',
#     '211192',
#     '211274',
#     '211453',
#     '211468',
#     '211537',
#     '211575',
#     '211748',
#     '211792',
#     '211803',
#     '211816',
#     '211820',
#     '212057',
#     '212083',
#     '212099',
#     '212198',
#     '212263',
#     '212302',
#     '212314',
#     '212339',
#     '212351',
#     '212421',
#     '212442',
#     '212484',
#     '212511',
#     '212516',
#     '212624',
#     '212678',
#     '212721',
#     '212769',
#     '212885',
#     '212905',
#     '213055',
#     '213112',
#     '213158',
#     '213189',
#     '213250',
#     '213334',
#     '213380',
#     '213420',
#     '213423',
#     '213557',
#     '213582',
#     '213601',
#     '213609',
#     '213628',
#     '213631',
#     '213643',
#     '213786',
#     '213879',
#     '213938',
#     '214077',
#     '214137',
#     '214172',
#     '214254',
#     '214650',
#     '214669',
#     '214680',
#     '214813',
#     '214946',
#     '215068',
#     '215106',
#     '215181',
#     '215198']},
#   {'section': 'B',
#    'class list': ['201018',
#     '201056',
#     '201103',
#     '201306',
#     '201350',
#     '201358',
#     '201462',
#     '201473',
#     '201752',
#     '201991',
#     '202041',
#     '202067',
#     '202074',
#     '202092',
#     '202161',
#     '202231',
#     '202243',
#     '202247',
#     '202269',
#     '202393',
#     '202410',
#     '202790',
#     '202806',
#     '202872',
#     '203142',
#     '203204',
#     '203225',
#     '203491',
#     '203763',
#     '203771',
#     '203810',
#     '203850',
#     '203859',
#     '203919',
#     '204016',
#     '204033',
#     '204165',
#     '204233',
#     '204281',
#     '204317',
#     '204377',
#     '204420',
#     '204522',
#     '204653',
#     '204667',
#     '204919',
#     '204944',
#     '204970',
#     '205028',
#     '205061',
#     '205102',
#     '205132',
#     '205149',
#     '205167',
#     '205219',
#     '205359',
#     '211006',
#     '211081',
#     '211126',
#     '211190',
#     '211201',
#     '211492',
#     '211530',
#     '211557',
#     '211740',
#     '211781',
#     '211863',
#     '211876',
#     '212110',
#     '212262',
#     '212546',
#     '212712',
#     '212883',
#     '212889',
#     '212908',
#     '212939',
#     '213067',
#     '213140',
#     '213152',
#     '213305',
#     '213381',
#     '213390',
#     '213400',
#     '213404',
#     '213435',
#     '213515',
#     '213551',
#     '213636',
#     '213717',
#     '213807',
#     '213812',
#     '214073',
#     '214123',
#     '214261',
#     '214295',
#     '214402',
#     '214459',
#     '214501',
#     '214510',
#     '214560',
#     '214578',
#     '214602',
#     '214605',
#     '214622',
#     '214643',
#     '214717',
#     '214718',
#     '214872',
#     '214988',
#     '215029',
#     '215057',
#     '215065',
#     '215110',
#     '215113',
#     '215182',
#     '215285']},
#   {'section': 'C',
#    'class list': ['201049',
#     '201089',
#     '201116',
#     '201138',
#     '201185',
#     '201236',
#     '201337',
#     '201493',
#     '201542',
#     '201699',
#     '201783',
#     '201814',
#     '201822',
#     '201907',
#     '202172',
#     '202189',
#     '202294',
#     '202454',
#     '202476',
#     '202495',
#     '202598',
#     '202767',
#     '202860',
#     '202888',
#     '202896',
#     '202956',
#     '202969',
#     '203000',
#     '203046',
#     '203080',
#     '203159',
#     '203223',
#     '203224',
#     '203317',
#     '203372',
#     '203529',
#     '203539',
#     '203678',
#     '203719',
#     '203772',
#     '203811',
#     '203838',
#     '203839',
#     '203884',
#     '203902',
#     '203936',
#     '203985',
#     '204002',
#     '204059',
#     '204229',
#     '204258',
#     '204413',
#     '204463',
#     '204603',
#     '204679',
#     '204691',
#     '204708',
#     '204815',
#     '204906',
#     '205116',
#     '205139',
#     '205144',
#     '205155',
#     '205191',
#     '205242',
#     '205254',
#     '205257',
#     '205286',
#     '205289',
#     '205341',
#     '211021',
#     '211038',
#     '211161',
#     '211258',
#     '211286',
#     '211300',
#     '211550',
#     '211573',
#     '211719',
#     '211830',
#     '211948',
#     '212001',
#     '212005',
#     '212009',
#     '212196',
#     '212225',
#     '212252',
#     '212284',
#     '212289',
#     '212383',
#     '212384',
#     '212453',
#     '212490',
#     '212499',
#     '212610',
#     '212819',
#     '212931',
#     '212954',
#     '213011',
#     '213017',
#     '213030',
#     '213048',
#     '213096',
#     '213184',
#     '213327',
#     '213524',
#     '213570',
#     '213700',
#     '213724',
#     '213739',
#     '213803',
#     '213826',
#     '213834',
#     '213910',
#     '214000',
#     '214273',
#     '214345',
#     '214471',
#     '214473',
#     '214496',
#     '214499',
#     '214686',
#     '214832',
#     '214839',
#     '214916',
#     '214952',
#     '214980',
#     '215172',
#     '215382']},
#   {'section': 'D',
#    'class list': ['201622',
#     '201668',
#     '201678',
#     '201703',
#     '201860',
#     '201900',
#     '201975',
#     '201978',
#     '202003',
#     '202045',
#     '202048',
#     '202090',
#     '202104',
#     '202136',
#     '202140',
#     '202275',
#     '202276',
#     '202295',
#     '202382',
#     '202467',
#     '202701',
#     '202722',
#     '202762',
#     '202816',
#     '202848',
#     '202949',
#     '202964',
#     '202974',
#     '203181',
#     '203207',
#     '203294',
#     '203308',
#     '203479',
#     '203544',
#     '203589',
#     '203590',
#     '203645',
#     '203680',
#     '203784',
#     '203858',
#     '203870',
#     '203951',
#     '203969',
#     '204013',
#     '204053',
#     '204212',
#     '204375',
#     '204407',
#     '204426',
#     '204614',
#     '204645',
#     '204744',
#     '204778',
#     '204866',
#     '204962',
#     '204997',
#     '205040',
#     '205056',
#     '205317',
#     '205336',
#     '205339',
#     '211002',
#     '211229',
#     '211362',
#     '211393',
#     '211476',
#     '211558',
#     '211659',
#     '211760',
#     '211812',
#     '211835',
#     '211903',
#     '211927',
#     '211999',
#     '212034',
#     '212142',
#     '212170',
#     '212240',
#     '212255',
#     '212266',
#     '212332',
#     '212425',
#     '212446',
#     '212565',
#     '212594',
#     '212602',
#     '212674',
#     '212710',
#     '212797',
#     '212839',
#     '212917',
#     '213060',
#     '213097',
#     '213136',
#     '213226',
#     '213364',
#     '213509',
#     '213535',
#     '213611',
#     '213878',
#     '213882',
#     '214054',
#     '214160',
#     '214226',
#     '214331',
#     '214515',
#     '214678',
#     '214849',
#     '215006',
#     '215016',
#     '215333']}],
#  'FA 24': [{'section': 'A',
#    'class list': ['201007',
#     '201048',
#     '201210',
#     '201290',
#     '201377',
#     '201402',
#     '201427',
#     '201439',
#     '201584',
#     '201586',
#     '201681',
#     '201732',
#     '201810',
#     '201845',
#     '201971',
#     '202011',
#     '202044',
#     '202175',
#     '202181',
#     '202316',
#     '202482',
#     '202509',
#     '202956',
#     '202997',
#     '203041',
#     '203045',
#     '203058',
#     '203092',
#     '203115',
#     '203304',
#     '203323',
#     '203460',
#     '203478',
#     '203597',
#     '203747',
#     '203972',
#     '204142',
#     '204332',
#     '204361',
#     '204427',
#     '204460',
#     '204543',
#     '204597',
#     '204663',
#     '204880',
#     '204902',
#     '205013',
#     '205018',
#     '205043',
#     '205059',
#     '205205',
#     '205228',
#     '205276',
#     '205277',
#     '205368',
#     '211100',
#     '211126',
#     '211148',
#     '211169',
#     '211243',
#     '211409',
#     '211414',
#     '211553',
#     '211664',
#     '211754',
#     '211770',
#     '212007',
#     '212014',
#     '212031',
#     '212094',
#     '212102',
#     '212162',
#     '212206',
#     '212314',
#     '212421',
#     '212448',
#     '212459',
#     '212488',
#     '212522',
#     '212593',
#     '212644',
#     '212672',
#     '212727',
#     '212786',
#     '212815',
#     '213057',
#     '213067',
#     '213124',
#     '213176',
#     '213232',
#     '213327',
#     '213356',
#     '213401',
#     '213665',
#     '213724',
#     '214248',
#     '214309',
#     '214337',
#     '214373',
#     '214384',
#     '214409',
#     '214516',
#     '214539',
#     '214578',
#     '214681',
#     '214774',
#     '214986',
#     '215057',
#     '215157',
#     '215182',
#     '215273',
#     '215312',
#     '215356',
#     '215390']},
#   {'section': 'B',
#    'class list': ['201297',
#     '201306',
#     '201383',
#     '201400',
#     '201419',
#     '201422',
#     '201487',
#     '201531',
#     '201686',
#     '201796',
#     '201819',
#     '201860',
#     '201991',
#     '202071',
#     '202085',
#     '202276',
#     '202403',
#     '202411',
#     '202423',
#     '202503',
#     '202660',
#     '202700',
#     '202767',
#     '202796',
#     '202915',
#     '202959',
#     '202969',
#     '202983',
#     '203111',
#     '203137',
#     '203200',
#     '203271',
#     '203309',
#     '203319',
#     '203425',
#     '203479',
#     '203566',
#     '203756',
#     '203766',
#     '203771',
#     '203849',
#     '203874',
#     '203979',
#     '204069',
#     '204230',
#     '204274',
#     '204323',
#     '204453',
#     '204503',
#     '204506',
#     '204535',
#     '204564',
#     '204567',
#     '204612',
#     '204745',
#     '204838',
#     '204921',
#     '204983',
#     '205080',
#     '205136',
#     '205315',
#     '211131',
#     '211145',
#     '211202',
#     '211205',
#     '211324',
#     '211528',
#     '211558',
#     '211582',
#     '211640',
#     '211784',
#     '211870',
#     '211877',
#     '212077',
#     '212170',
#     '212178',
#     '212186',
#     '212212',
#     '212241',
#     '212286',
#     '212581',
#     '212751',
#     '212793',
#     '212886',
#     '212995',
#     '213076',
#     '213105',
#     '213138',
#     '213155',
#     '213257',
#     '213429',
#     '213463',
#     '213464',
#     '213467',
#     '213499',
#     '213622',
#     '213792',
#     '213932',
#     '213934',
#     '213950',
#     '214005',
#     '214064',
#     '214114',
#     '214141',
#     '214156',
#     '214173',
#     '214219',
#     '214236',
#     '214357',
#     '214410',
#     '214474',
#     '214512',
#     '214641',
#     '214660',
#     '214756',
#     '214820',
#     '214826',
#     '214836',
#     '214865',
#     '214908',
#     '214990',
#     '215172',
#     '215246',
#     '215371']},
#   {'section': 'C',
#    'class list': ['201077',
#     '201312',
#     '201442',
#     '201486',
#     '201574',
#     '201632',
#     '201673',
#     '201771',
#     '201800',
#     '201827',
#     '201843',
#     '201846',
#     '201978',
#     '202000',
#     '202213',
#     '202264',
#     '202313',
#     '202378',
#     '202551',
#     '202588',
#     '202768',
#     '202794',
#     '202909',
#     '203033',
#     '203199',
#     '203296',
#     '203353',
#     '203407',
#     '203422',
#     '203477',
#     '203580',
#     '203680',
#     '203843',
#     '203884',
#     '203889',
#     '203919',
#     '203962',
#     '204126',
#     '204165',
#     '204180',
#     '204207',
#     '204317',
#     '204598',
#     '204615',
#     '204667',
#     '204842',
#     '204863',
#     '205028',
#     '205099',
#     '205116',
#     '205166',
#     '205197',
#     '205225',
#     '211102',
#     '211142',
#     '211187',
#     '211229',
#     '211351',
#     '211476',
#     '211577',
#     '211658',
#     '211894',
#     '211918',
#     '211938',
#     '212118',
#     '212210',
#     '212238',
#     '212441',
#     '212508',
#     '212586',
#     '212670',
#     '212671',
#     '212736',
#     '212788',
#     '212858',
#     '213065',
#     '213129',
#     '213393',
#     '213408',
#     '213420',
#     '213489',
#     '213503',
#     '213533',
#     '213596',
#     '213647',
#     '213658',
#     '213746',
#     '213762',
#     '213930',
#     '213955',
#     '214288',
#     '214690',
#     '214705',
#     '214734',
#     '214847',
#     '214940',
#     '215002',
#     '215078',
#     '215085',
#     '215094',
#     '215107',
#     '215133',
#     '215196',
#     '215200',
#     '215278',
#     '215398',
#     '215401',
#     '215404']},
#   {'section': 'D',
#    'class list': ['201003',
#     '201231',
#     '201307',
#     '201392',
#     '201410',
#     '201434',
#     '201450',
#     '201499',
#     '202015',
#     '202036',
#     '202257',
#     '202269',
#     '202337',
#     '202352',
#     '202407',
#     '202410',
#     '202445',
#     '202447',
#     '202531',
#     '202590',
#     '202854',
#     '202860',
#     '202862',
#     '202976',
#     '203043',
#     '203192',
#     '203206',
#     '203243',
#     '203320',
#     '203344',
#     '203350',
#     '203372',
#     '203411',
#     '203486',
#     '203544',
#     '203845',
#     '203856',
#     '203872',
#     '203875',
#     '203921',
#     '204039',
#     '204043',
#     '204052',
#     '204084',
#     '204095',
#     '204278',
#     '204380',
#     '204408',
#     '204542',
#     '204547',
#     '204691',
#     '204805',
#     '204819',
#     '204870',
#     '204879',
#     '204881',
#     '204907',
#     '205008',
#     '205041',
#     '205047',
#     '205077',
#     '205353',
#     '211141',
#     '211192',
#     '211387',
#     '211598',
#     '211625',
#     '211634',
#     '211682',
#     '211782',
#     '211847',
#     '211865',
#     '211999',
#     '212030',
#     '212052',
#     '212105',
#     '212107',
#     '212365',
#     '212431',
#     '212446',
#     '212622',
#     '212737',
#     '212805',
#     '212830',
#     '212835',
#     '212932',
#     '212960',
#     '213015',
#     '213072',
#     '213166',
#     '213208',
#     '213413',
#     '213451',
#     '213552',
#     '213634',
#     '213988',
#     '214014',
#     '214079',
#     '214176',
#     '214251',
#     '214467',
#     '214475',
#     '214589',
#     '214624',
#     '214759',
#     '214773',
#     '214839',
#     '214854',
#     '214917',
#     '215084',
#     '215113',
#     '215217',
#     '215394']}],
#  'FX 96': [{'section': 'A',
#    'class list': ['201070',
#     '201086',
#     '201099',
#     '201114',
#     '201121',
#     '201125',
#     '201200',
#     '201226',
#     '201291',
#     '201318',
#     '201321',
#     '201340',
#     '201354',
#     '201378',
#     '201383',
#     '201402',
#     '201404',
#     '201417',
#     '201439',
#     '201455',
#     '201473',
#     '201563',
#     '201578',
#     '201581',
#     '201585',
#     '201604',
#     '201693',
#     '201696',
#     '201720',
#     '201729',
#     '201750',
#     '201753',
#     '201766',
#     '201786',
#     '201787',
#     '201800',
#     '201822',
#     '201826',
#     '201911',
#     '201926',
#     '201941',
#     '201953',
#     '201957',
#     '201963',
#     '201971',
#     '201974',
#     '201978',
#     '202013',
#     '202019',
#     '202038',
#     '202055',
#     '202070',
#     '202074',
#     '202132',
#     '202155',
#     '202203',
#     '202209',
#     '202232',
#     '202254',
#     '202259',
#     '202292',
#     '202303',
#     '202335',
#     '202354',
#     '202360',
#     '202363',
#     '202397',
#     '202458',
#     '202510',
#     '202512',
#     '202521',
#     '202548',
#     '202557',
#     '202596',
#     '202619',
#     '202655',
#     '202686',
#     '202706',
#     '202731',
#     '202764',
#     '202775',
#     '202817',
#     '202821',
#     '202848',
#     '202861',
#     '202862',
#     '202893',
#     '202959',
#     '202962',
#     '202963',
#     '202980',
#     '202981',
#     '203019',
#     '203023',
#     '203035',
#     '203041',
#     '203102',
#     '203103',
#     '203114',
#     '203148',
#     '203156',
#     '203164',
#     '203171',
#     '203172',
#     '203185',
#     '203187',
#     '203204',
#     '203230',
#     '203280',
#     '203297',
#     '203316',
#     '203335',
#     '203339',
#     '203357',
#     '203362',
#     '203365',
#     '203371',
#     '203397',
#     '203399',
#     '203419',
#     '203483',
#     '203485',
#     '203511',
#     '203523',
#     '203534',
#     '203555',
#     '203566',
#     '203569',
#     '203580',
#     '203583',
#     '203593',
#     '203599',
#     '203614',
#     '203679',
#     '203710',
#     '203730',
#     '203738',
#     '203741',
#     '203758',
#     '203767',
#     '203773',
#     '203787',
#     '203800',
#     '203829',
#     '203831',
#     '203854',
#     '203859',
#     '203876',
#     '203921',
#     '203924',
#     '203949',
#     '203986',
#     '204003',
#     '204030',
#     '204035',
#     '204036',
#     '204040',
#     '204043',
#     '204069',
#     '204108',
#     '204111',
#     '204126',
#     '204148',
#     '204159',
#     '204175',
#     '204180',
#     '204194',
#     '204198',
#     '204222',
#     '204278',
#     '204305',
#     '204307',
#     '204316',
#     '204333',
#     '204342',
#     '204361',
#     '204375',
#     '204376',
#     '204393',
#     '204395',
#     '204404',
#     '204429',
#     '204442',
#     '204443',
#     '204460',
#     '204461',
#     '204476',
#     '204490',
#     '204524',
#     '204580',
#     '204587',
#     '204595',
#     '204606',
#     '204631',
#     '204640',
#     '204651',
#     '204658',
#     '204676',
#     '204687',
#     '204697',
#     '204781',
#     '204802',
#     '204805',
#     '204808',
#     '204818',
#     '204833',
#     '204838',
#     '204860',
#     '204880',
#     '204883',
#     '204928',
#     '204951',
#     '204999',
#     '205015',
#     '205025',
#     '205031',
#     '205054',
#     '205061',
#     '205075',
#     '205097',
#     '205100',
#     '205112',
#     '205117',
#     '205241',
#     '205251',
#     '205260',
#     '205263',
#     '205275',
#     '205283',
#     '205288',
#     '205317',
#     '205342',
#     '205358',
#     '205359',
#     '205408',
#     '211009',
#     '211020',
#     '211075',
#     '211079',
#     '211088',
#     '211100',
#     '211112',
#     '211123',
#     '211149',
#     '211151',
#     '211155',
#     '211176',
#     '211190',
#     '211201',
#     '211259',
#     '211329',
#     '211346',
#     '211353',
#     '211373',
#     '211408',
#     '211424',
#     '211444',
#     '211468',
#     '211485',
#     '211491',
#     '211492',
#     '211518',
#     '211520',
#     '211572',
#     '211575',
#     '211590',
#     '211606',
#     '211637',
#     '211640',
#     '211651',
#     '211652',
#     '211665',
#     '211666',
#     '211707',
#     '211708',
#     '211713',
#     '211740',
#     '211765',
#     '211770',
#     '211805',
#     '211813',
#     '211821',
#     '211823',
#     '211828',
#     '211836',
#     '211856',
#     '211904',
#     '211913',
#     '211927',
#     '211934',
#     '211958',
#     '211970',
#     '211988',
#     '211992',
#     '212025',
#     '212031',
#     '212034',
#     '212080',
#     '212086',
#     '212106',
#     '212119',
#     '212126',
#     '212133',
#     '212166',
#     '212171',
#     '212180',
#     '212187',
#     '212192',
#     '212195',
#     '212236',
#     '212241',
#     '212268',
#     '212280',
#     '212308',
#     '212365',
#     '212366',
#     '212370',
#     '212389',
#     '212400',
#     '212421',
#     '212425',
#     '212431',
#     '212477',
#     '212480',
#     '212496',
#     '212498',
#     '212499',
#     '212520',
#     '212522',
#     '212549',
#     '212570',
#     '212578',
#     '212586',
#     '212595',
#     '212601',
#     '212613',
# ...
#     '213359',
#     '213363',
#     '213373',
#     '213376',
#     '213408',
#     '213412',
#     '213420',
#     '213424',
#     '213435',
#     '213449',
#     '213452',
#     '213461',
#     '213465',
#     '213487',
#     '213494',
#     '213496',
#     '213533',
#     '213541',
#     '213557',
#     '213560',
#     '213592',
#     '213660',
#     '213674',
#     '213682',
#     '213693',
#     '213711',
#     '213749',
#     '213750',
#     '213769',
#     '213776',
#     '213778',
#     '213780',
#     '213782',
#     '213786',
#     '213814',
#     '213820',
#     '213830',
#     '213851',
#     '213866',
#     '213891',
#     '213918',
#     '213929',
#     '213939',
#     '213943',
#     '214022',
#     '214027',
#     '214057',
#     '214071',
#     '214081',
#     '214087',
#     '214090',
#     '214091',
#     '214096',
#     '214101',
#     '214104',
#     '214146',
#     '214156',
#     '214157',
#     '214196',
#     '214216',
#     '214218',
#     '214226',
#     '214239',
#     '214240',
#     '214249',
#     '214280',
#     '214303',
#     '214350',
#     '214351',
#     '214364',
#     '214381',
#     '214400',
#     '214421',
#     '214467',
#     '214477',
#     '214489',
#     '214500',
#     '214505',
#     '214510',
#     '214526',
#     '214534',
#     '214536',
#     '214586',
#     '214588',
#     '214602',
#     '214657',
#     '214672',
#     '214674',
#     '214678',
#     '214693',
#     '214699',
#     '214769',
#     '214776',
#     '214780',
#     '214806',
#     '214832',
#     '214878',
#     '214887',
#     '214901',
#     '214942',
#     '214949',
#     '214954',
#     '214955',
#     '214961',
#     '214992',
#     '215076',
#     '215084',
#     '215085',
#     '215094',
#     '215118',
#     '215120',
#     '215158',
#     '215171',
#     '215172',
#     '215194',
#     '215201',
#     '215221',
#     '215232',
#     '215237',
#     '215256',
#     '215326',
#     '215331',
#     '215373',
#     '215379',
#     '215394',
#     '215396',
#     '215400',
#     '215403']}],
#  'ZJ 82': [{'section': 'A',
#    'class list': ['201101',
#     '201150',
#     '201179',
#     '201185',
#     '201294',
#     '201421',
#     '201542',
#     '201731',
#     '201751',
#     '201773',
#     '201857',
#     '201933',
#     '202015',
#     '202222',
#     '202235',
#     '202479',
#     '202491',
#     '202639',
#     '202691',
#     '202792',
#     '202976',
#     '203031',
#     '203218',
#     '203223',
#     '203247',
#     '203280',
#     '203309',
#     '203310',
#     '203426',
#     '203427',
#     '203572',
#     '203692',
#     '203926',
#     '203970',
#     '204135',
#     '204320',
#     '204338',
#     '204339',
#     '204623',
#     '204655',
#     '204679',
#     '204720',
#     '204764',
#     '204985',
#     '205066',
#     '205075',
#     '205156',
#     '205320',
#     '211046',
#     '211079',
#     '211119',
#     '211205',
#     '211211',
#     '211639',
#     '211707',
#     '211749',
#     '211779',
#     '211792',
#     '211861',
#     '212030',
#     '212116',
#     '212186',
#     '212233',
#     '212334',
#     '212389',
#     '212420',
#     '212502',
#     '212594',
#     '212625',
#     '212710',
#     '212761',
#     '212774',
#     '212795',
#     '212829',
#     '212856',
#     '212920',
#     '212943',
#     '213025',
#     '213257',
#     '213333',
#     '213341',
#     '213352',
#     '213636',
#     '213641',
#     '213668',
#     '213791',
#     '213815',
#     '213840',
#     '213851',
#     '214056',
#     '214176',
#     '214265',
#     '214271',
#     '214358',
#     '214369',
#     '214411',
#     '214627',
#     '214724',
#     '214783',
#     '214807',
#     '214813',
#     '214856',
#     '214961',
#     '215127',
#     '215237',
#     '215391']},
#   {'section': 'B',
#    'class list': ['201013',
#     '201058',
#     '201226',
#     '201321',
#     '201419',
#     '201428',
#     '201451',
#     '201503',
#     '201714',
#     '201806',
#     '202000',
#     '202140',
#     '202153',
#     '202168',
#     '202295',
#     '202590',
#     '202636',
#     '202899',
#     '202994',
#     '202997',
#     '203171',
#     '203214',
#     '203306',
#     '203332',
#     '203388',
#     '203543',
#     '203740',
#     '203848',
#     '203897',
#     '203999',
#     '204012',
#     '204069',
#     '204116',
#     '204185',
#     '204224',
#     '204241',
#     '204259',
#     '204267',
#     '204522',
#     '204542',
#     '204547',
#     '204750',
#     '204755',
#     '204915',
#     '205177',
#     '205179',
#     '205324',
#     '211047',
#     '211292',
#     '211352',
#     '211477',
#     '211549',
#     '211644',
#     '211712',
#     '211817',
#     '211882',
#     '211981',
#     '212145',
#     '212146',
#     '212162',
#     '212195',
#     '212485',
#     '212693',
#     '212717',
#     '212814',
#     '212958',
#     '213136',
#     '213220',
#     '213361',
#     '213367',
#     '213380',
#     '213420',
#     '213582',
#     '213714',
#     '213837',
#     '213914',
#     '213953',
#     '213980',
#     '214010',
#     '214202',
#     '214423',
#     '214669',
#     '214670',
#     '214859',
#     '214894',
#     '215010',
#     '215020',
#     '215084',
#     '215106',
#     '215229',
#     '215404']},
#   {'section': 'C',
#    'class list': ['201045',
#     '201063',
#     '201068',
#     '201090',
#     '201156',
#     '201159',
#     '201318',
#     '201355',
#     '201392',
#     '201411',
#     '201525',
#     '201545',
#     '201562',
#     '201663',
#     '201780',
#     '201800',
#     '201898',
#     '202003',
#     '202008',
#     '202070',
#     '202249',
#     '202264',
#     '202320',
#     '202392',
#     '202398',
#     '202419',
#     '202460',
#     '202476',
#     '202599',
#     '202607',
#     '202608',
#     '202860',
#     '202868',
#     '202950',
#     '203018',
#     '203201',
#     '203301',
#     '203430',
#     '203480',
#     '203600',
#     '203703',
#     '203799',
#     '203865',
#     '204019',
#     '204030',
#     '204034',
#     '204118',
#     '204276',
#     '204312',
#     '204444',
#     '204504',
#     '204626',
#     '204676',
#     '204979',
#     '205041',
#     '205149',
#     '205226',
#     '205329',
#     '205347',
#     '205361',
#     '211008',
#     '211109',
#     '211373',
#     '211494',
#     '211541',
#     '211630',
#     '211674',
#     '211894',
#     '211988',
#     '212069',
#     '212245',
#     '212273',
#     '212306',
#     '212318',
#     '212412',
#     '212440',
#     '212466',
#     '212484',
#     '212629',
#     '212712',
#     '212923',
#     '213003',
#     '213253',
#     '213489',
#     '213501',
#     '213507',
#     '213609',
#     '213830',
#     '213863',
#     '213961',
#     '213977',
#     '213996',
#     '214058',
#     '214149',
#     '214190',
#     '214283',
#     '214334',
#     '214344',
#     '214402',
#     '214534',
#     '214607',
#     '214791',
#     '214882',
#     '215004',
#     '215203',
#     '215234']},
#   {'section': 'D',
#    'class list': ['201089',
#     '201210',
#     '201236',
#     '201305',
#     '201425',
#     '201555',
#     '201691',
#     '201739',
#     '201873',
#     '202002',
#     '202046',
#     '202174',
#     '202232',
#     '202358',
#     '202615',
#     '202642',
#     '202657',
#     '202791',
#     '202821',
#     '202827',
#     '202967',
#     '203653',
#     '203691',
#     '203733',
#     '203742',
#     '203761',
#     '203805',
#     '203846',
#     '203976',
#     '204068',
#     '204210',
#     '204275',
#     '204348',
#     '204376',
#     '204397',
#     '204455',
#     '204778',
#     '204808',
#     '204833',
#     '204862',
#     '204960',
#     '205211',
#     '205263',
#     '211031',
#     '211036',
#     '211367',
#     '211527',
#     '211547',
#     '211616',
#     '211700',
#     '211862',
#     '211931',
#     '212004',
#     '212023',
#     '212053',
#     '212196',
#     '212449',
#     '212483',
#     '212505',
#     '212539',
#     '212553',
#     '212578',
#     '212597',
#     '212697',
#     '212797',
#     '212805',
#     '212813',
#     '212835',
#     '212841',
#     '212864',
#     '212897',
#     '213028',
#     '213263',
#     '213381',
#     '213494',
#     '213681',
#     '213793',
#     '213929',
#     '214011',
#     '214273',
#     '214301',
#     '214351',
#     '214386',
#     '214509',
#     '214747',
#     '214854',
#     '214922',
#     '215037',
#     '215044',
#     '215071',
#     '215073',
#     '215083',
#     '215159',
#     '215163']},
#   {'section': 'E',
#    'class list': ['201004',
#     '201017',
#     '201082',
#     '201220',
#     '201299',
#     '201337',
#     '201350',
#     '201415',
#     '201559',
#     '201576',
#     '201588',
#     '201747',
#     '201807',
#     '201810',
#     '201839',
#     '201923',
#     '202029',
#     '202098',
#     '202348',
#     '202627',
#     '202846',
#     '202904',
#     '203170',
#     '203514',
#     '203529',
#     '203536',
#     '203723',
#     '203880',
#     '203905',
#     '203982',
#     '203984',
#     '204107',
#     '204215',
#     '204305',
#     '204394',
#     '204405',
#     '204721',
#     '204857',
#     '204909',
#     '205018',
#     '205178',
#     '205248',
#     '205302',
#     '211021',
#     '211161',
#     '211176',
#     '211222',
#     '211258',
#     '211538',
#     '211650',
#     '211782',
#     '212040',
#     '212402',
#     '212427',
#     '212589',
#     '212725',
#     '212736',
#     '212883',
#     '212948',
#     '212982',
#     '213002',
#     '213179',
#     '213209',
#     '213274',
#     '213337',
#     '213436',
#     '213441',
#     '213465',
#     '213512',
#     '213634',
#     '213737',
#     '213746',
#     '213906',
#     '214141',
#     '214321',
#     '214391',
#     '214459',
#     '214525',
#     '214550',
#     '214671',
#     '214701',
#     '214893',
#     '215114',
#     '215243',
#     '215410']}],
#  'ZP 68': [{'section': 'A',
#    'class list': ['201003',
#     '201005',
#     '201050',
#     '201052',
#     '201056',
#     '201076',
#     '201078',
#     '201093',
#     '201138',
#     '201152',
#     '201153',
#     '201156',
#     '201172',
#     '201198',
#     '201212',
#     '201224',
#     '201248',
#     '201255',
#     '201257',
#     '201269',
#     '201272',
#     '201279',
#     '201333',
#     '201358',
#     '201359',
#     '201361',
#     '201374',
#     '201415',
#     '201422',
#     '201427',
#     '201440',
#     '201467',
#     '201471',
#     '201505',
#     '201515',
#     '201519',
#     '201531',
#     '201564',
#     '201565',
#     '201578',
#     '201609',
#     '201619',
#     '201621',
#     '201657',
#     '201669',
#     '201727',
#     '201739',
#     '201743',
#     '201755',
#     '201772',
#     '201773',
#     '201834',
#     '201895',
#     '201909',
#     '201914',
#     '201922',
#     '201954',
#     '201975',
#     '201990',
#     '202029',
#     '202044',
#     '202046',
#     '202054',
#     '202059',
#     '202091',
#     '202104',
#     '202108',
#     '202143',
#     '202144',
#     '202150',
#     '202161',
#     '202173',
#     '202181',
#     '202197',
#     '202230',
#     '202248',
#     '202250',
#     '202264',
#     '202269',
#     '202276',
#     '202330',
#     '202354',
#     '202373',
#     '202392',
#     '202410',
#     '202478',
#     '202479',
#     '202554',
#     '202576',
#     '202580',
#     '202607',
#     '202619',
#     '202626',
#     '202632',
#     '202642',
#     '202650',
#     '202662',
#     '202683',
#     '202691',
#     '202695',
#     '202722',
#     '202726',
#     '202741',
#     '202756',
#     '202768',
#     '202811',
#     '202823',
#     '202868',
#     '202893',
#     '202913',
#     '202964',
#     '202997',
#     '203001',
#     '203016',
#     '203020',
#     '203023',
#     '203034',
#     '203035',
#     '203039',
#     '203142',
#     '203147',
#     '203153',
#     '203156',
#     '203168',
#     '203196',
#     '203233',
#     '203246',
#     '203284',
#     '203299',
#     '203302',
#     '203323',
#     '203338',
#     '203344',
#     '203392',
#     '203473',
#     '203485',
#     '203491',
#     '203493',
#     '203537',
#     '203547',
#     '203612',
#     '203646',
#     '203659',
#     '203698',
#     '203703',
#     '203757',
#     '203779',
#     '203781',
#     '203787',
#     '203819',
#     '203829',
#     '203854',
#     '203867',
#     '203885',
#     '203890',
#     '203893',
#     '203920',
#     '203937',
#     '203969',
#     '203970',
#     '203985',
#     '204002',
#     '204019',
#     '204035',
#     '204047',
#     '204051',
#     '204066',
#     '204086',
#     '204089',
#     '204107',
#     '204117',
#     '204126',
#     '204133',
#     '204142',
#     '204153',
#     '204169',
#     '204207',
#     '204215',
#     '204247',
#     '204277',
#     '204286',
#     '204340',
#     '204376',
#     '204377',
#     '204390',
#     '204404',
#     '204407',
#     '204426',
#     '204441',
#     '204460',
#     '204465',
#     '204476',
#     '204485',
#     '204502',
#     '204521',
#     '204533',
#     '204551',
#     '204562',
#     '204564',
#     '204616',
#     '204652',
#     '204661',
#     '204665',
#     '204726',
#     '204746',
#     '204775',
#     '204786',
#     '204858',
#     '204866',
#     '204985',
#     '205038',
#     '205043',
#     '205062',
#     '205069',
#     '205081',
#     '205088',
#     '205101',
#     '205108',
#     '205146',
#     '205177',
#     '205178',
#     '205258',
#     '205259',
#     '205277',
#     '205287',
#     '205299',
#     '205302',
#     '205329',
#     '205375',
#     '205376',
#     '205383',
#     '205393',
#     '205402',
#     '211012',
#     '211055',
#     '211065',
#     '211088',
#     '211098',
#     '211111',
#     '211113',
#     '211165',
#     '211167',
#     '211182',
#     '211186',
#     '211219',
#     '211223',
#     '211240',
#     '211241',
#     '211244',
#     '211251',
#     '211256',
#     '211332',
#     '211388',
#     '211399',
#     '211409',
#     '211414',
#     '211420',
#     '211435',
#     '211443',
#     '211446',
#     '211491',
#     '211523',
#     '211528',
#     '211538',
#     '211552',
#     '211561',
#     '211596',
#     '211600',
#     '211610',
#     '211626',
#     '211628',
#     '211641',
#     '211650',
#     '211656',
#     '211660',
#     '211689',
#     '211712',
#     '211733',
#     '211745',
#     '211785',
#     '211808',
#     '211821',
#     '211840',
#     '211861',
#     '211904',
#     '211910',
#     '211925',
#     '211928',
#     '211940',
#     '211944',
#     '212018',
#     '212025',
#     '212028',
#     '212057',
#     '212079',
#     '212084',
#     '212089',
#     '212097',
#     '212109',
#     '212112',
#     '212119',
#     '212162',
#     '212166',
#     '212188',
#     '212217',
#     '212262',
#     '212280',
#     '212285',
#     '212299',
#     '212300',
#     '212318',
#     '212323',
#     '212332',
#     '212353',
#     '212375',
#     '212381',
#     '212400',
#     '212405',
#     '212426',
#     '212442',
#     '212453',
#     '212469',
#     '212477',
#     '212506',
#     '212516',
#     '212537',
#     '212541',
#     '212542',
#     '212561',
#     '212603',
#     '212611',
#     '212629',
#     '212637',
#     '212643',
#     '212644',
#     '212667',
#     '212673',
#     '212716',
#     '212765',
#     '212766',
#     '212779',
#     '212784',
#     '212808',
#     '212836',
#     '212853',
#     '212877',
#     '212905',
#     '212930',
#     '212936',
#     '212946',
#     '212961',
#     '213042',
#     '213049',
#     '213055',
#     '213068',
#     '213074',
#     '213126',
#     '213128',
#     '213146',
#     '213152',
#     '213189',
#     '213220',
#     '213227',
#     '213261',
#     '213307',
#     '213318',
#     '213333',
#     '213360',
#     '213364',
#     '213370',
#     '213376',
#     '213380',
#     '213384',
#     '213385',
#     '213387',
#     '213412',
#     '213423',
#     '213442',
#     '213443',
#     '213455',
#     '213462',
#     '213464',
#     '213470',
#     '213472',
#     '213494',
#     '213497',
#     '213532',
#     '213545',
#     '213548',
#     '213552',
#     '213558',
#     '213564',
#     '213567',
#     '213588',
#     '213591',
#     '213601',
#     '213615',
#     '213626',
#     '213640',
#     '213648',
#     '213661',
#     '213666',
#     '213669',
#     '213697',
#     '213718',
#     '213732',
#     '213768',
#     '213793',
#     '213794',
#     '213820',
#     '213835',
#     '213841',
#     '213861',
#     '213879',
#     '213881',
#     '213910',
#     '213929',
#     '213947',
#     '213953',
#     '214000',
#     '214014',
#     '214042',
#     '214056',
#     '214087',
#     '214130',
#     '214156',
#     '214161',
#     '214166',
#     '214184',
#     '214187',
#     '214204',
#     '214239',
#     '214251',
#     '214280',
#     '214285',
#     '214300',
#     '214324',
#     '214337',
#     '214345',
#     '214349',
#     '214373',
#     '214430',
#     '214440',
#     '214462',
#     '214469',
#     '214481',
#     '214494',
#     '214501',
#     '214511',
#     '214514',
#     '214523',
#     '214536',
#     '214545',
#     '214559',
#     '214560',
#     '214584',
#     '214588',
#     '214674',
#     '214686',
#     '214688',
#     '214714',
#     '214724',
#     '214740',
#     '214743',
#     '214752',
#     '214753',
#     '214757',
#     '214759',
#     '214774',
#     '214777',
#     '214783',
#     '214796',
#     '214806',
#     '214807',
#     '214820',
#     '214825',
#     '214836',
#     '214843',
#     '214851',
#     '214874',
#     '214916',
#     '214932',
#     '214942',
#     '214946',
#     '214956',
#     '214959',
#     '214969',
#     '214972',
#     '214973',
#     '214980',
#     '215007',
#     '215011',
#     '215012',
#     '215027',
#     '215048',
#     '215050',
#     '215065',
#     '215076',
#     '215085',
#     '215105',
#     '215114',
#     '215142',
#     '215148',
#     '215165',
#     '215174',
#     '215183',
#     '215193',
#     '215244',
#     '215247',
#     '215250',
#     '215303',
#     '215331',
#     '215337',
#     '215344',
#     '215396',
#     '215403']}]}

# %% [markdown]
# ## Section 3: Payroll (65 points)

# %% [markdown]
# ### Context
#
# A startup decides to avoid hiring regular employees for now. Instead, they have been engaging consultants and interns to support them in their current operations. There are not a lot of people, but preparation is tedious.
#
# All consultants and interns get paid at the end of the month.
#
# Interns are expected to render 20 hours of work each month. The actual number of hours worked by each intern is then prorated against the monthly fee stated in their contract. For example, if an intern works 20 hours, then the disbursement will be 100%. If another intern works for only 11, the payout will be 11/20 or 55%.
#
# If interns go overtime in the month, they get a premium of 200% on their hourly rate for anything in excess of 20 hours. The hourly rate is computed as follows:
#
# *hourly rate = contracted monthly fee / 20*
#
# The startup works on an honesty system. In lieu of timesheets, each intern is given a link to Google Forms where they specify their temporary company ID and the number of hours they rendered for the month. All entries are then logged in an associated Google Sheets document. Human Resources then is able to export the spreadsheet into a CSV that looks like so (for the month of July, 2021, as contained in the file **./section3/interns-timelog-july-2021.csv**):
#
# ```
# id,hours_rendered
# 2021001,20
# 2021002,17
# 2021003,16
# 2021004,15
# 2021005,16
# 2021006,18
# 2021007,17
# 2021008,17
# 2021009,15
# 2021010,18
# 2021011,16
# 2021012,20
# 2021013,18
# 2021014,22
# 2021015,20
# 2021016,25
# 2021017,20
# 2021018,17
# 2021019,20
# 2021020,18
# ```
#
# At the company's discretion, certain employees are given work-from-home (WFH) privileges. If an intern has been tagged to be given a WFH allowance, an additional P300 is given.
#
# In addition, the intern gets to designate one of two banks (BPI, BDO) for payroll crediting.
#
# The intern masterfile, saved from a central database as csv, is shown below:
#
# ```
# id,bank,account_number,monthly_fee,wfh
# 2021001,BPI,1093 5000 5001,4500,Y
# 2021002,BPI,1093 5000 5002,3500,Y
# 2021003,BPI,1093 5000 5003,4500,Y
# 2021004,BPI,1093 5000 5004,4500,Y
# 2021005,BPI,1093 5000 5005,6000,Y
# 2021006,BPI,1093 5000 5006,4500,Y
# 2021007,BPI,1093 5000 5007,5000,Y
# 2021008,BPI,1093 5000 5008,4500,Y
# 2021009,BPI,1093 5000 5009,4500,N
# 2021010,BPI,1093 5000 5010,6000,N
# 2021011,BPI,1093 5000 5011,4500,N
# 2021012,BPI,1093 5000 5012,3500,N
# 2021013,BPI,1093 5000 5013,4500,N
# 2021014,BPI,1093 5000 5014,4500,N
# 2021015,BPI,1093 5000 5015,5000,Y
# 2021016,BPI,1093 5000 5016,4500,Y
# 2021017,BPI,1093 5000 5017,6000,Y
# 2021018,BPI,1093 5000 5018,3500,Y
# 2021019,BPI,1093 5000 5019,4500,Y
# 2021020,BPI,1093 5000 5020,4500,Y
# ```
#
# Consultants are paid in full (with no accounting for time); however, their take home pay is their contracted monthly fee less 10%. For example, if one consultant's gross pay is P100,000, the amount to be disbursed is P100,000 less 10% = P90,000. For another consultant that insists on P100,000 as net amount, it will be the company's burden to shoulder the taxes; this arrangement is commonly known as "grossing up". In the case of gross-up, if the disbursement needs to preserve P100,000.00, the contracted monthly fee is P111,111.11.
#
# Similar to interns, certain consultants are provided WFH allowance.
#
# The consultant masterlist is shown below:
#
# ```
# tin,bank,account_number,monthly_fee,wfh
# 151-500-200-000,BPI,1093 5000 6001,100000,Y
# 151-500-201-000,BPI,1093 5000 6002,50000,Y
# 151-500-202-000,BDO,0078 0000 0001,111111.11,Y
# 151-500-203-000,BPI,1093 5000 6004,100000,Y
# 151-500-204-000,BPI,1093 5000 6005,65000,Y
# 151-500-205-000,BPI,1093 5000 6006,130000,Y
# 151-500-206-000,BDO,0078 0000 0002,50000,Y
# 151-500-207-000,BDO,0078 0000 0003,45000,Y
# 151-500-208-000,BPI,1093 5000 6007,45000,N
# 151-500-209-000,BPI,1093 5000 6008,60000,N
# 151-500-210-000,BPI,1093 5000 6009,45000,N
# ```

# %% [markdown]
# ### 3.1

# %% [markdown]
# #### 3.1.1
#
# Write a function **get_utilization** with an argument **hours_rendered** and returns utilization (not percentage).

# %%
# CODE CELL

# CODE START
def get_utilization(hours_rendered):
    
    utilization = hours_rendered/20
    if hours_rendered > 20:
        utilization = float(1)
    return utilization

    pass



# CODE END

# %% [markdown]
# #### 3.1.2
#
# Write a function **get_pay** with four arguments: **monthly_fee**, **hours_rendered**, **overtime**, and **wfh_allowance**. It then returns the computed takehome pay as float.
#
# This function will presumably call **get_utilization**.

# %%
# CODE CELL
# def get_pay(monthly_fee, hours_rendered, overtime_fee, wfh_allowance):
# CODE START
def get_pay(monthly_fee, hours_rendered, overtime_pay, wfh_allowance):
    
    takehome_pay = (monthly_fee * get_utilization(hours_rendered)) + wfh_allowance + get_overtime_pay(monthly_fee,hours_rendered)
    
    return takehome_pay
    
    pass
    # Replace this with your code

# CODE END

# %% [markdown]
# #### 3.1.3
#
# Write a function **get_overtime_pay** that accepts **hours_rendered** and **monthly_fee** as parameters and then returns the amount of overtime to credit to the intern.

# %%
# CODE CELL

# CODE START
def get_overtime_pay(monthly_fee,hours_rendered):
    
    if hours_rendered > 20:
        overtime_pay = (hours_rendered - 20)*((monthly_fee/20)*2)
    else:
        overtime_pay = 0
        
    return overtime_pay
    pass

# %% [markdown]
# You may run the cell below to test your code.

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it!

# Expected output: 2250.0
get_overtime_pay(4500,25)
# Out:
# 2250.0

# %% [markdown]
# ### 3.2: For Interns

# %% [markdown]
# #### 3.2.1
#
# Create a list variable named `raw_log` that contains dictionaries (or ordered dictionaries if you use the DictReader method of the Python csv module) for each entry in the time-and-attendance log file **./section3/interns-timelogs-july2021.csv**.

# %%
# CODE CELL
import csv
raw_log = []

# CODE START

with open("./section3/interns-timelogs-july2021.csv","r") as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        raw_log.append(row)

# CODE END
        
# sample dump of raw_log in interactive mode
raw_log
# Out:
# [{'id': '2021001', 'hours_rendered': '20'},
#  {'id': '2021002', 'hours_rendered': '17'},
#  {'id': '2021003', 'hours_rendered': '16'},
#  {'id': '2021004', 'hours_rendered': '15'},
#  {'id': '2021005', 'hours_rendered': '16'},
#  {'id': '2021006', 'hours_rendered': '18'},
#  {'id': '2021007', 'hours_rendered': '17'},
#  {'id': '2021008', 'hours_rendered': '17'},
#  {'id': '2021009', 'hours_rendered': '15'},
#  {'id': '2021010', 'hours_rendered': '18'},
#  {'id': '2021011', 'hours_rendered': '16'},
#  {'id': '2021012', 'hours_rendered': '20'},
#  {'id': '2021013', 'hours_rendered': '18'},
#  {'id': '2021014', 'hours_rendered': '22'},
#  {'id': '2021015', 'hours_rendered': '20'},
#  {'id': '2021016', 'hours_rendered': '25'},
#  {'id': '2021017', 'hours_rendered': '20'},
#  {'id': '2021018', 'hours_rendered': '17'},
#  {'id': '2021019', 'hours_rendered': '20'},
#  {'id': '2021020', 'hours_rendered': '18'}]

# %% [markdown]
# #### 3.2.2
#
# To retrieve details about individual interns quickly, it's best that we store intern data in a dictionary. This way, we simply lookup the details of the intern by key (in this case, the **id**).
#
# Create a dictionary variable named **interns_master_dict** that contains dictionaries for each entry in the intern master file file **./section3/interns-masterlist.csv**.

# %%
# CODE CELL
import csv


# CODE START
reader = csv.DictReader(open('./section3/interns_masterlist.csv'))

interns_master_dict = {}
for row in reader:
    key = row.pop('id')
    if key in interns_master_dict:

        pass
    interns_master_dict[key] = row


# CODE END

# sample dump of raw_log in interactive mode
# https://stackoverflow.com/questions/14091387/creating-a-dictionary-from-a-csv-file/14091464
interns_master_dict
# Out:
# {'2021001': {'bank': 'BPI',
#   'account_number': '1093 5000 5001',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021002': {'bank': 'BPI',
#   'account_number': '1093 5000 5002',
#   'monthly_fee': '3500',
#   'wfh': 'Y'},
#  '2021003': {'bank': 'BPI',
#   'account_number': '1093 5000 5003',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021004': {'bank': 'BPI',
#   'account_number': '1093 5000 5004',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021005': {'bank': 'BPI',
#   'account_number': '1093 5000 5005',
#   'monthly_fee': '6000',
#   'wfh': 'Y'},
#  '2021006': {'bank': 'BPI',
#   'account_number': '1093 5000 5006',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021007': {'bank': 'BPI',
#   'account_number': '1093 5000 5007',
#   'monthly_fee': '5000',
#   'wfh': 'Y'},
#  '2021008': {'bank': 'BPI',
#   'account_number': '1093 5000 5008',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021009': {'bank': 'BPI',
#   'account_number': '1093 5000 5009',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021010': {'bank': 'BPI',
#   'account_number': '1093 5000 5010',
#   'monthly_fee': '6000',
#   'wfh': 'N'},
#  '2021011': {'bank': 'BPI',
#   'account_number': '1093 5000 5011',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021012': {'bank': 'BPI',
#   'account_number': '1093 5000 5012',
#   'monthly_fee': '3500',
#   'wfh': 'N'},
#  '2021013': {'bank': 'BPI',
#   'account_number': '1093 5000 5013',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021014': {'bank': 'BPI',
#   'account_number': '1093 5000 5014',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021015': {'bank': 'BPI',
#   'account_number': '1093 5000 5015',
#   'monthly_fee': '5000',
#   'wfh': 'Y'},
#  '2021016': {'bank': 'BPI',
#   'account_number': '1093 5000 5016',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021017': {'bank': 'BPI',
#   'account_number': '1093 5000 5017',
#   'monthly_fee': '6000',
#   'wfh': 'Y'},
#  '2021018': {'bank': 'BPI',
#   'account_number': '1093 5000 5018',
#   'monthly_fee': '3500',
#   'wfh': 'Y'},
#  '2021019': {'bank': 'BPI',
#   'account_number': '1093 5000 5019',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021020': {'bank': 'BPI',
#   'account_number': '1093 5000 5020',
#   'monthly_fee': '4500',
#   'wfh': 'Y'}}

# %% [markdown]
# #### 3.2.3
#
# Create a new list variable **interns_payroll** based on raw_logs but with an additional key takehome_pay for each dictionary entry.

# %%
# CODE CELL

interns_payroll = raw_log

# CODE START

for i in raw_log:
    
    i['monthly_fee'] = int(interns_master_dict[str(i['id'])]['monthly_fee'])
    i['overtime_pay'] = (get_overtime_pay(i['monthly_fee'],int(i['hours_rendered'])))
    i['prorated_pay'] = (get_utilization(int(i['hours_rendered'])) * i['monthly_fee'])
    
    
    if interns_master_dict[i['id']]['wfh'] == 'Y':
        i['wfh_allowance'] = 300
    else:
        i['wfh_allowance'] = 0
        
    i['takehome_pay'] = get_pay(i['monthly_fee'], int(i['hours_rendered']), i['overtime_pay'], i['wfh_allowance'])
    
    
    

# CODE END
                 
# sample dump of payroll in interactive mode
interns_payroll
# Out:
# [{'id': '2021001',
#   'hours_rendered': '20',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 4500.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4800.0},
#  {'id': '2021002',
#   'hours_rendered': '17',
#   'monthly_fee': 3500,
#   'overtime_pay': 0,
#   'prorated_pay': 2975.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3275.0},
#  {'id': '2021003',
#   'hours_rendered': '16',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 3600.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3900.0},
#  {'id': '2021004',
#   'hours_rendered': '15',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 3375.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3675.0},
#  {'id': '2021005',
#   'hours_rendered': '16',
#   'monthly_fee': 6000,
#   'overtime_pay': 0,
#   'prorated_pay': 4800.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 5100.0},
#  {'id': '2021006',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 4050.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4350.0},
#  {'id': '2021007',
#   'hours_rendered': '17',
#   'monthly_fee': 5000,
#   'overtime_pay': 0,
#   'prorated_pay': 4250.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4550.0},
#  {'id': '2021008',
#   'hours_rendered': '17',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 3825.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4125.0},
#  {'id': '2021009',
#   'hours_rendered': '15',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 3375.0,
#   'wfh_allowance': 0,
#   'takehome_pay': 3375.0},
#  {'id': '2021010',
#   'hours_rendered': '18',
#   'monthly_fee': 6000,
#   'overtime_pay': 0,
#   'prorated_pay': 5400.0,
#   'wfh_allowance': 0,
#   'takehome_pay': 5400.0},
#  {'id': '2021011',
#   'hours_rendered': '16',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 3600.0,
#   'wfh_allowance': 0,
#   'takehome_pay': 3600.0},
#  {'id': '2021012',
#   'hours_rendered': '20',
#   'monthly_fee': 3500,
#   'overtime_pay': 0,
#   'prorated_pay': 3500.0,
#   'wfh_allowance': 0,
#   'takehome_pay': 3500.0},
#  {'id': '2021013',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 4050.0,
#   'wfh_allowance': 0,
#   'takehome_pay': 4050.0},
#  {'id': '2021014',
#   'hours_rendered': '22',
#   'monthly_fee': 4500,
#   'overtime_pay': 900.0,
#   'prorated_pay': 4500.0,
#   'wfh_allowance': 0,
#   'takehome_pay': 5400.0},
#  {'id': '2021015',
#   'hours_rendered': '20',
#   'monthly_fee': 5000,
#   'overtime_pay': 0,
#   'prorated_pay': 5000.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 5300.0},
#  {'id': '2021016',
#   'hours_rendered': '25',
#   'monthly_fee': 4500,
#   'overtime_pay': 2250.0,
#   'prorated_pay': 4500.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 7050.0},
#  {'id': '2021017',
#   'hours_rendered': '20',
#   'monthly_fee': 6000,
#   'overtime_pay': 0,
#   'prorated_pay': 6000.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 6300.0},
#  {'id': '2021018',
#   'hours_rendered': '17',
#   'monthly_fee': 3500,
#   'overtime_pay': 0,
#   'prorated_pay': 2975.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3275.0},
#  {'id': '2021019',
#   'hours_rendered': '20',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 4500.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4800.0},
#  {'id': '2021020',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'overtime_pay': 0,
#   'prorated_pay': 4050.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4350.0}]

# %% [markdown]
# #### 3.2.4
#
# Looping through the new list variable **payroll**, generate an intern payslip print spool file for the month of July. The time logs (as illustrated above) may be found in the file **./section3/interns-timelog-july2021.csv**.
#
# The output must be saved in a file named **./output/interns-payslips-july2021.txt**. The output looks like the following:
#
# ```
# Payroll Date   : July 31, 2021
# ID             : 2021001
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 20
# ------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021002
# Monthly Fee       : 3500
# ------------------------------
# Hours Rendered : 17
# ------------------------------
# Prorated Pay   : 2975.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 3275.0
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021013
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 18
# ------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# Takehome Pay   : 4050.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021014
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 22
# ------------------------------
# Prorated Pay   : 4950.0
# Overtime Pay   : 900.0
# Takehome Pay   : 5400.0
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021019
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 20
# ------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021020
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 18
# ------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4350.0
#
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2020
# ID             : 2021009
# Base Pay       : 4,500
# ------------------------------
# Hours Rendered : 15
# Takehome Pay   : 3,375.00
# ...
#
# ```
#
# **VERY IMPORTANT:** If the intern does not have a WFH allowance arrangement, **DO NOT** print out the line 'WFH Allowance'!!! The company does not want interns to ask about that if they see that line since it will open a can of worms.

# %%
# CODE CELL
import csv

filename = "./output/interns-payslips-july2021.txt"
payroll_run_date = "July 31, 2021"
# CODE START

with open(filename, 'w') as csvfile:
    for i in interns_payroll:
        csvfile.write(f'''________________________________________\n
Payroll Date\t: {payroll_run_date}
ID\t\t: {i['id']}
Monthly Fee\t: {i['monthly_fee']}
----------------------------------------
Hours Rendered: {i['hours_rendered']}
----------------------------------------
Prorated Pay\t: {i['prorated_pay']}
Overtime Pay\t: {i['overtime_pay']}\n''')
        if i['wfh_allowance'] == 0:
            pass
        else:
            csvfile.write(f"WFH Allowance\t: {i['wfh_allowance']}\n")
    
        csvfile.write(f'''Takehome Pay\t: {i['takehome_pay']}\n\n''')


# CODE END

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it.

# See the output of your file
# !cat "./output/interns-payslips-july2021.txt"
# Out:
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021001
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 20
# ----------------------------------------
# Prorated Pay	: 4500.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4800.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021002
# Monthly Fee	: 3500
# ----------------------------------------
# Hours Rendered: 17
# ----------------------------------------
# Prorated Pay	: 2975.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3275.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021003
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 16
# ----------------------------------------
# Prorated Pay	: 3600.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3900.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021004
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 15
# ----------------------------------------
# Prorated Pay	: 3375.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3675.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021005
# Monthly Fee	: 6000
# ----------------------------------------
# Hours Rendered: 16
# ----------------------------------------
# Prorated Pay	: 4800.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 5100.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021006
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 18
# ----------------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4350.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021007
# Monthly Fee	: 5000
# ----------------------------------------
# Hours Rendered: 17
# ----------------------------------------
# Prorated Pay	: 4250.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4550.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021008
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 17
# ----------------------------------------
# Prorated Pay	: 3825.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4125.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021009
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 15
# ----------------------------------------
# Prorated Pay	: 3375.0
# Overtime Pay	: 0
# Takehome Pay	: 3375.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021010
# Monthly Fee	: 6000
# ----------------------------------------
# Hours Rendered: 18
# ----------------------------------------
# Prorated Pay	: 5400.0
# Overtime Pay	: 0
# Takehome Pay	: 5400.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021011
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 16
# ----------------------------------------
# Prorated Pay	: 3600.0
# Overtime Pay	: 0
# Takehome Pay	: 3600.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021012
# Monthly Fee	: 3500
# ----------------------------------------
# Hours Rendered: 20
# ----------------------------------------
# Prorated Pay	: 3500.0
# Overtime Pay	: 0
# Takehome Pay	: 3500.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021013
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 18
# ----------------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# Takehome Pay	: 4050.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021014
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 22
# ----------------------------------------
# Prorated Pay	: 4500.0
# Overtime Pay	: 900.0
# Takehome Pay	: 5400.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021015
# Monthly Fee	: 5000
# ----------------------------------------
# Hours Rendered: 20
# ----------------------------------------
# Prorated Pay	: 5000.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 5300.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021016
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 25
# ----------------------------------------
# Prorated Pay	: 4500.0
# Overtime Pay	: 2250.0
# WFH Allowance	: 300
# Takehome Pay	: 7050.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021017
# Monthly Fee	: 6000
# ----------------------------------------
# Hours Rendered: 20
# ----------------------------------------
# Prorated Pay	: 6000.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 6300.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021018
# Monthly Fee	: 3500
# ----------------------------------------
# Hours Rendered: 17
# ----------------------------------------
# Prorated Pay	: 2975.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3275.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021019
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 20
# ----------------------------------------
# Prorated Pay	: 4500.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4800.0
#
# ________________________________________
#
# Payroll Date	: July 31, 2021
# ID		: 2021020
# Monthly Fee	: 4500
# ----------------------------------------
# Hours Rendered: 18
# ----------------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4350.0

# %% [markdown]
# ### 3.3: For Consultants

# %% [markdown]
# Create a regular CSV named **./output/consultants_payouts_july2021.csv** containing consultant payout amounts. Use **./section3/consultants_masterlist.csv** as basis for the amounts, then don't forget to deduct 10% withholding tax.
#
# ```
# tin,net_pay
# 151-500-200-000,90000.00
# ...
# 151-500-202-000,100000.00
# ...
#
# ```

# %% [markdown]
# Create a dictionary **consultants_master_dict** containing lookups for consultants.

# %%
# CODE CELL
import csv
consultants_master_dict = {}
# CODE START

with open('./section3/consultants_masterlist.csv', 'r') as masterdict:
    masterdict = csv.DictReader(masterdict)
    for rows in masterdict:
        consultants_master_dict[rows['tin']] = {'bank': rows['bank'], 'account_number': rows['account_number']}

# https://stackoverflow.com/questions/14091387/creating-a-dictionary-from-a-csv-file/14091464
# CODE END
consultants_master_dict
# Out:
# {'151-500-200-000': {'bank': 'BPI', 'account_number': '1093 5000 6001'},
#  '151-500-201-000': {'bank': 'BPI', 'account_number': '1093 5000 6002'},
#  '151-500-202-000': {'bank': 'BDO', 'account_number': '0078 0000 0001'},
#  '151-500-203-000': {'bank': 'BPI', 'account_number': '1093 5000 6004'},
#  '151-500-204-000': {'bank': 'BPI', 'account_number': '1093 5000 6005'},
#  '151-500-205-000': {'bank': 'BPI', 'account_number': '1093 5000 6006'},
#  '151-500-206-000': {'bank': 'BDO', 'account_number': '0078 0000 0002'},
#  '151-500-207-000': {'bank': 'BDO', 'account_number': '0078 0000 0003'},
#  '151-500-208-000': {'bank': 'BPI', 'account_number': '1093 5000 6007'},
#  '151-500-209-000': {'bank': 'BPI', 'account_number': '1093 5000 6008'},
#  '151-500-210-000': {'bank': 'BPI', 'account_number': '1093 5000 6009'}}

# %% [markdown]
# Unlike the interns, we don't need to give consultants payslips. However, it would be easier to run "payroll" for consultants and store the results in a staging file. Run the consultants' "payroll" by keeping the results in a list variable called **consultants_payroll**. Each element of this list is based on a corresponding role in **./section3/consultants_masterlist.csv**. To make it easier, create a **consultants_fees** list variable by reading from this file.
#
# Then, generate a consultant payout file named **./output/consultants_payouts_july2021.csv**.

# %%
# CODE CELL

import csv
consultants_fees = []

#input_file = "./section3/consultants_masterlist.csv"
# CODE START

with open("./section3/consultants_masterlist.csv","r") as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        consultants_fees.append(row)

# CODE END

# dump output
consultants_fees
# Out:
# [{'tin': '151-500-200-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6001',
#   'monthly_fee': '100000',
#   'wfh': 'Y'},
#  {'tin': '151-500-201-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6002',
#   'monthly_fee': '50000',
#   'wfh': 'Y'},
#  {'tin': '151-500-202-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0001',
#   'monthly_fee': '111111.11',
#   'wfh': 'Y'},
#  {'tin': '151-500-203-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6004',
#   'monthly_fee': '100000',
#   'wfh': 'Y'},
#  {'tin': '151-500-204-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6005',
#   'monthly_fee': '65000',
#   'wfh': 'Y'},
#  {'tin': '151-500-205-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6006',
#   'monthly_fee': '130000',
#   'wfh': 'Y'},
#  {'tin': '151-500-206-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0002',
#   'monthly_fee': '50000',
#   'wfh': 'Y'},
#  {'tin': '151-500-207-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0003',
#   'monthly_fee': '45000',
#   'wfh': 'Y'},
#  {'tin': '151-500-208-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6007',
#   'monthly_fee': '45000',
#   'wfh': 'N'},
#  {'tin': '151-500-209-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6008',
#   'monthly_fee': '60000',
#   'wfh': 'N'},
#  {'tin': '151-500-210-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6009',
#   'monthly_fee': '45000',
#   'wfh': 'N'}]

# %%
# CODE CELL
consultants_payroll = []

# CODE START

for i in consultants_fees:
    consultants_payroll.append({'tin': i['tin'], 'net_pay' : 0.9*(float(i['monthly_fee']))})
    
with open ('./output/consultants_payouts_july2021.csv', 'w') as payouts:
    field_names = ['tin', 'net_pay']
    payoutdict = csv.DictWriter(payouts, fieldnames = field_names)
    payoutdict.writeheader()
    
    for row in consultants_payroll:
        payoutdict.writerow({'tin' : row['tin'], 'net_pay' : row['net_pay']})

# CODE END

# sample dump of raw_log in interactive mode
consultants_payroll
# Out:
# [{'tin': '151-500-200-000', 'net_pay': 90000.0},
#  {'tin': '151-500-201-000', 'net_pay': 45000.0},
#  {'tin': '151-500-202-000', 'net_pay': 99999.999},
#  {'tin': '151-500-203-000', 'net_pay': 90000.0},
#  {'tin': '151-500-204-000', 'net_pay': 58500.0},
#  {'tin': '151-500-205-000', 'net_pay': 117000.0},
#  {'tin': '151-500-206-000', 'net_pay': 45000.0},
#  {'tin': '151-500-207-000', 'net_pay': 40500.0},
#  {'tin': '151-500-208-000', 'net_pay': 40500.0},
#  {'tin': '151-500-209-000', 'net_pay': 54000.0},
#  {'tin': '151-500-210-000', 'net_pay': 40500.0}]

# %% [markdown]
# To check if your payout file contents are correct, run `cat` (if using MacOS) or `type` (if using Windows). Don't forget the "!" character before the command. Replace `cat` with `type` if you are on Windows.

# %%
# !cat "./output/consultants_payouts_july2021.csv"
# Out:
# tin,net_pay
# 151-500-200-000,90000.0
# 151-500-201-000,45000.0
# 151-500-202-000,99999.999
# 151-500-203-000,90000.0
# 151-500-204-000,58500.0
# 151-500-205-000,117000.0
# 151-500-206-000,45000.0
# 151-500-207-000,40500.0
# 151-500-208-000,40500.0
# 151-500-209-000,54000.0
# 151-500-210-000,40500.0

# %% [markdown]
# ### 3.4: Bank Credit Advise

# %% [markdown]
# **B. Bank Credit Advise**
#
# Generate a credit advise file each for BPI and BDO covering interns and consultants. The files must be named **./output/su-bpi-payment-advise.csv** and **./output/su-bdo-payment-advise.csv** respectively and should look like the following:
#
# ```
# account_number,amount
# 109350005001,4800.0
# 109350005002,3275.0
# ...
# 109350005003,3375.0
# ...
# 109350006001,9000
# ```

# %%
# CODE CELL
bpi_advise = []
bdo_advise = []

# CODE START

for i in interns_payroll:
    if interns_master_dict[i['id']]['bank'] == 'BPI':
        bpi_advise.append({'account_number' : interns_master_dict[i['id']]['account_number'], "amount" : i['takehome_pay']})
    elif interns_master_dict[i['id']]['bank']:
        bdo_advise.append({'account_number' : interns_master_dict[i['id']]['account_number'], "amount" : i['takehome_pay']})
        
        
for j in consultants_payroll:
    if consultants_master_dict[j['tin']]['bank'] == 'BPI':
        bpi_advise.append({'account_number' : consultants_master_dict[j['tin']]['account_number'], "amount" : j['net_pay']})
    elif consultants_master_dict[j['tin']]['bank'] == 'BDO':
        bdo_advise.append({'account_number' : consultants_master_dict[j['tin']]['account_number'], "amount" : j['net_pay']})
        
        
with open ('./output/su-bpi-payment-advise.csv', 'w') as bpicsv:
    field_names = ['account_number', 'amount']
    bpidict = csv.DictWriter(bpicsv, fieldnames = field_names)
    bpidict.writeheader()
    
    for row in bpi_advise:
        bpidict.writerow({'account_number' : row['account_number'], 'amount' : row['amount']})
        
with open ('./output/su-bdo-payment-advise.csv', 'w') as bdocsv:
    field_names = ['account_number', 'amount']
    bdodict = csv.DictWriter(bdocsv, fieldnames = field_names)
    bdodict.writeheader()
    
    for row in bdo_advise:
        bdodict.writerow({'account_number' : row['account_number'], 'amount' : row['amount']})

# CODE END

# %%
bpi_advise
# Out:
# [{'account_number': '1093 5000 5001', 'amount': 4800.0},
#  {'account_number': '1093 5000 5002', 'amount': 3275.0},
#  {'account_number': '1093 5000 5003', 'amount': 3900.0},
#  {'account_number': '1093 5000 5004', 'amount': 3675.0},
#  {'account_number': '1093 5000 5005', 'amount': 5100.0},
#  {'account_number': '1093 5000 5006', 'amount': 4350.0},
#  {'account_number': '1093 5000 5007', 'amount': 4550.0},
#  {'account_number': '1093 5000 5008', 'amount': 4125.0},
#  {'account_number': '1093 5000 5009', 'amount': 3375.0},
#  {'account_number': '1093 5000 5010', 'amount': 5400.0},
#  {'account_number': '1093 5000 5011', 'amount': 3600.0},
#  {'account_number': '1093 5000 5012', 'amount': 3500.0},
#  {'account_number': '1093 5000 5013', 'amount': 4050.0},
#  {'account_number': '1093 5000 5014', 'amount': 5400.0},
#  {'account_number': '1093 5000 5015', 'amount': 5300.0},
#  {'account_number': '1093 5000 5016', 'amount': 7050.0},
#  {'account_number': '1093 5000 5017', 'amount': 6300.0},
#  {'account_number': '1093 5000 5018', 'amount': 3275.0},
#  {'account_number': '1093 5000 5019', 'amount': 4800.0},
#  {'account_number': '1093 5000 5020', 'amount': 4350.0},
#  {'account_number': '1093 5000 6001', 'amount': 90000.0},
#  {'account_number': '1093 5000 6002', 'amount': 45000.0},
#  {'account_number': '1093 5000 6004', 'amount': 90000.0},
#  {'account_number': '1093 5000 6005', 'amount': 58500.0},
#  {'account_number': '1093 5000 6006', 'amount': 117000.0},
#  {'account_number': '1093 5000 6007', 'amount': 40500.0},
#  {'account_number': '1093 5000 6008', 'amount': 54000.0},
#  {'account_number': '1093 5000 6009', 'amount': 40500.0}]

# %%
bdo_advise
# Out:
# [{'account_number': '0078 0000 0001', 'amount': 99999.999},
#  {'account_number': '0078 0000 0002', 'amount': 45000.0},
#  {'account_number': '0078 0000 0003', 'amount': 40500.0}]

# %% [markdown]
# To check if your file outputs are correct, run either cat (on MacOS) or type (on Windows) below. Just replace `cat` with `type` if you're using Windows.

# %%
# !cat "./output/su-bpi-payment-advise.csv"
# Out:
# account_number,amount
# 1093 5000 5001,4800.0
# 1093 5000 5002,3275.0
# 1093 5000 5003,3900.0
# 1093 5000 5004,3675.0
# 1093 5000 5005,5100.0
# 1093 5000 5006,4350.0
# 1093 5000 5007,4550.0
# 1093 5000 5008,4125.0
# 1093 5000 5009,3375.0
# 1093 5000 5010,5400.0
# 1093 5000 5011,3600.0
# 1093 5000 5012,3500.0
# 1093 5000 5013,4050.0
# 1093 5000 5014,5400.0
# 1093 5000 5015,5300.0
# 1093 5000 5016,7050.0
# 1093 5000 5017,6300.0
# 1093 5000 5018,3275.0
# 1093 5000 5019,4800.0
# 1093 5000 5020,4350.0
# 1093 5000 6001,90000.0
# 1093 5000 6002,45000.0
# 1093 5000 6004,90000.0
# 1093 5000 6005,58500.0
# 1093 5000 6006,117000.0
# 1093 5000 6007,40500.0
# 1093 5000 6008,54000.0
# 1093 5000 6009,40500.0

# %%
# !cat './output/su-bdo-payment-advise.csv'
# Out:
# account_number,amount
# 0078 0000 0001,99999.999
# 0078 0000 0002,45000.0
# 0078 0000 0003,40500.0
